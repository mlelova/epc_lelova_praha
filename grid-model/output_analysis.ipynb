# %% [markdown]
# ## Model vs TYNDP 2030 NT — Fundamental Comparison
#
# Comparing PyPSA dispatch model (`solved_baseline6.nc`, CY2009) against TYNDP 2024 National Trends 2030 Plexos reference (CY2009).
#
# **Data sources:**
# - Model: `scenarios/networks/solved_baseline6.nc` — PyPSA linear dispatch optimisation
# - Reference: `MMStandardOutputFile_NT2030_Plexos_CY2009_2.5_v40 3.xlsx` — TYNDP 2024 NT Plexos
#
# **Sections:**
# 0. Installed capacity + full load hours — Europe-wide and per-bus
# 1. Annual generation mix — Europe-wide stacked bars
# 2. Per-bus generation comparison — heatmap of relative differences
# 3. DE00 monthly generation detail
# 4. Annual LMP — all buses (scatter + ranked bar)
# 5. Monthly LMP — DE00 detail
# 6. Net trade balance — all buses
# 7. Summary statistics table

# %%
import pypsa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.append('../scenario_analysis')
from plot_utils import (
    apply_thesis_style, thesis_subplots, save_fig,
    CARRIER_COLORS, SCALE_COLORS, SCALE_MARKERS,
    POSITIVE, NEGATIVE, NEUTRAL, REFLINE,
)
apply_thesis_style()

NETWORK_FILE = "../scenarios/baseline_networks/solved_baseline6.nc"
XLSX = "../data/tyndp2024/MMStandardOutputFile_NT2030_Plexos_CY2009_2.5_v40 3.xlsx"
FOCUS_BUS = "DE00"
MONTH_NAMES = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]

n = pypsa.Network(NETWORK_FILE)
print(f"Loaded: {len(n.buses)} buses | {len(n.generators)} generators | {len(n.storage_units)} storage units")
print(f"Period: {n.snapshots[0]} to {n.snapshots[-1]}  ({len(n.snapshots)} h)")
print(f"\nGenerator carriers:")
for car, cnt in n.generators["carrier"].value_counts().items():
    print(f"  {car}: {cnt}")
# Out:
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 1.0.7)
# INFO:pypsa.network.io:Imported network 'TYNDP2024_Electricity_2030' has buses, carriers, generators, links, loads, storage_units, sub_networks
# Loaded: 55 buses | 559 generators | 119 storage units
# Period: 2030-01-01 00:00:00 to 2030-12-31 23:00:00  (8760 h)
#
# Generator carriers:
#   dsr: 78
#   gas: 76
#   slack: 55
#   other-thermal: 50
#   onwind: 49
#   other-res: 42
#   solar-pv-utility: 40
#   hydro-ror: 37
#   solar-pv-rooftop: 36
#   offwind: 26
#   nuclear: 14
#   oil-light: 12
#   coal: 11
#   lignite: 10
#   oil-heavy: 7
#   solar-thermal: 5
#   h2-ccgt: 5
#   solar-thermal-w-storage: 3
#   gas-ccs: 1
#   oil-shale: 1
#   h2-fuel-cell: 1

# %%
# Parse XLSX "Yearly Outputs" sheet
# Structure:
#   Row 5  (index 5)  : headers — col 0+1 = "Output type", col 2+ = bus codes
#   Rows 6-55 (gen)   : col 0 = section label (first row only), col 1 = tech name, col 2+ = GWh/yr
#   Row 57            : Native Demand [GWh]
#   Row 59            : Net annual country balance [GWh]  (positive = net export)
#   Row 218           : Marginal Cost Yearly Average (excl. 3000 cap) [EUR/MWh]

raw = pd.read_excel(XLSX, sheet_name="Yearly Outputs", header=None, engine="openpyxl")

# Bus codes: row index 5, starting from column 2
bus_row = raw.iloc[5]
bus_col_idx_all = {}
for ci in range(2, raw.shape[1]):
    v = str(bus_row[ci]).strip()
    if v != "nan":
        bus_col_idx_all[v] = ci

# Remap UK00/UKNI before filtering
for old, new in [("UK00", "GB00"), ("UKNI", "GBNI")]:
    if old in bus_col_idx_all:
        bus_col_idx_all[new] = bus_col_idx_all.pop(old)

# Filter to only buses present in the PyPSA model
model_bus_set = set(n.buses.index)
bus_col_idx = {bus: ci for bus, ci in bus_col_idx_all.items() if bus in model_bus_set}

only_tyndp = sorted(set(bus_col_idx_all) - model_bus_set)
only_model = sorted(model_bus_set - set(bus_col_idx_all))

print(f"TYNDP buses total:   {len(bus_col_idx_all)}")
print(f"Model buses total:   {len(model_bus_set)}")
print(f"Common buses:        {len(bus_col_idx)}")
print(f"\nTYNDP-only (excluded from comparison): {only_tyndp}")
print(f"Model-only  (no TYNDP reference):      {only_model}")

# Print tech rows
print("\nGeneration rows 6-55 (all 50 technologies):")
de_ci = bus_col_idx.get("DE00")
for i in range(6, 56):
    tech = str(raw.iloc[i, 1]).strip()
    de_val = f"{float(raw.iloc[i, de_ci]):>10.0f} GWh" if de_ci and str(raw.iloc[i, de_ci]) != "nan" else "?"
    print(f"  row {i:3d}: {tech:<45}  DE00={de_val}")
# Out:
# TYNDP buses total:   77
# Model buses total:   55
# Common buses:        53
#
# TYNDP-only (excluded from comparison): ['BEOF', 'DEKF', 'DKBH', 'DKKF', 'DKNS', 'DZ00', 'EEOF', 'EG00', 'GE00', 'IL00', 'IS00', 'LTOF', 'LY00', 'MA00', 'MD00', 'NL60', 'NL6H', 'NLA0', 'NLBH', 'NLLL', 'PS00', 'TN00', 'TR00', 'UA00']
# Model-only  (no TYNDP reference):      ['ITCO', 'ITVI']
#
# Generation rows 6-55 (all 50 technologies):
#   row   6: Nuclear                                        DE00=         0 GWh
#   row   7: Lignite old 1                                  DE00=         0 GWh
#   row   8: Lignite old 2                                  DE00=         0 GWh
#   row   9: Lignite new                                    DE00=         0 GWh
#   row  10: Lignite CCS                                    DE00=         0 GWh
#   row  11: Hard coal old 1                                DE00=         0 GWh
#   row  12: Hard coal old 2                                DE00=         0 GWh
# ...

# %%
# Category mappings — both TYNDP and model map to the same simplified categories

TYNDP_CAT = {
    "nuclear":                                  "Nuclear",
    "lignite":                                  "Lignite",
    "hard coal":                                "Coal",
    "gas ccgt":                                 "Gas",
    "gas conventional":                         "Gas",
    "gas ocgt":                                 "Gas",
    "light oil":                                "Oil",
    "heavy oil":                                "Oil",
    "oil shale":                                "Oil",
    "run-of-river":                             "Hydro RoR",
    "reservoir":                                "Hydro Reservoir",
    "pondage":                                  "Hydro Reservoir",
    "pump storage - open loop (turbine)":       "Hydro PHS",
    "pump storage - closed loop (turbine)":     "Hydro PHS",
    "pump storage - open loop (pump)":          None,   # charging — skip
    "pump storage - closed loop (pump)":        None,   # charging — skip
    "wind onshore":                             "Wind Onshore",
    "wind offshore":                            "Wind Offshore",
    "solar (photovoltaic)":                     "Solar PV",
    "solar (thermal)":                          "Solar PV",
    "others renewable":                         "Other RES",
    "biofuel":                                  "Other RES",
    "others non-renewable":                     "Other Thermal",
    "battery storage discharge":                "Battery",
    "battery storage charge":                   None,
    "electrolyser":                             None,
    "hydrogen fuel cell":                       "Hydrogen",
    "hydrogen ccgt":                            "Hydrogen",
    "demand side response":                     "DSR",
}

# PyPSA carrier → same simplified category
# slack = optimization artifact, excluded
PYPSA_CAT = {
    "nuclear":                  "Nuclear",
    "lignite":                  "Lignite",
    "coal":                     "Coal",
    "gas":                      "Gas",
    "gas-ccs":                  "Gas",
    "oil-light":                "Oil",
    "oil-heavy":                "Oil",
    "oil-shale":                "Oil",
    "hydro-ror":                "Hydro RoR",
    "hydro-reservoir":          "Hydro Reservoir",
    "hydro-pondage":            "Hydro Reservoir",  # storage unit
    "hydro-phs":                "Hydro PHS",        # storage unit
    "hydro-phs-pure":           "Hydro PHS",        # storage unit
    "offwind":                  "Wind Offshore",
    "onwind":                   "Wind Onshore",
    "solar-pv-utility":         "Solar PV",
    "solar-pv-rooftop":         "Solar PV",
    "solar-thermal":            "Solar PV",
    "solar-thermal-w-storage":  "Solar PV",
    "other-res":                "Other RES",
    "other-thermal":            "Other Thermal",
    "battery":                  "Battery",          # storage unit
    "h2-ccgt":                  "Hydrogen",
    "h2-fuel-cell":             "Hydrogen",
    "dsr":                      "DSR",
    "slack":                    None,               # exclude
}

CAT_COLORS = {
    "Nuclear":          "#7B2D8B",
    "Lignite":          "#5D4037",
    "Coal":             "#795548",
    "Gas":              "#F57F17",
    "Oil":              "#B71C1C",
    "Hydro Reservoir":  "#0D47A1",
    "Hydro RoR":        "#1565C0",
    "Hydro PHS":        "#42A5F5",
    "Wind Onshore":     "#388E3C",
    "Wind Offshore":    "#1B5E20",
    "Solar PV":         "#FDD835",
    "Battery":          "#00ACC1",
    "Hydrogen":         "#AB47BC",
    "Other RES":        "#66BB6A",
    "Other Thermal":    "#78909C",
    "DSR":              "#FF7043",
}

CAT_ORDER = [
    "Nuclear", "Lignite", "Coal", "Gas", "Oil", "Other Thermal",
    "Hydro Reservoir", "Hydro RoR", "Hydro PHS",
    "Wind Onshore", "Wind Offshore", "Solar PV",
    "Battery", "Hydrogen", "Other RES", "DSR",
]

def classify_tyndp(name: str):
    nl = name.lower().strip()
    best_key, best_cat = "", "Other Thermal"
    for key, cat in TYNDP_CAT.items():
        if key in nl and len(key) > len(best_key):
            best_key, best_cat = key, cat
    return best_cat

def carrier_to_cat(carrier: str):
    return PYPSA_CAT.get(carrier.lower(), None)  # None = unknown/skip

# --- Build TYNDP generation DataFrame (only common buses, GWh/yr) ---
gen_data_t = {bus: {} for bus in bus_col_idx}
for row_i in range(6, 56):
    tech = str(raw.iloc[row_i, 1]).strip()
    if tech == "nan":
        continue
    cat = classify_tyndp(tech)
    if cat is None:
        continue
    for bus, ci in bus_col_idx.items():
        try:
            val = float(raw.iloc[row_i, ci])
        except (ValueError, TypeError):
            val = 0.0
        gen_data_t[bus][cat] = gen_data_t[bus].get(cat, 0.0) + val

tyndp_gen = pd.DataFrame(gen_data_t).T.fillna(0)
tyndp_gen = tyndp_gen.reindex(columns=[c for c in CAT_ORDER if c in tyndp_gen.columns], fill_value=0)
tyndp_gen_twh = tyndp_gen / 1000  # GWh → TWh

def row_series(row_idx):
    return pd.Series({bus: float(raw.iloc[row_idx, ci])
                      for bus, ci in bus_col_idx.items()}, dtype=float)

tyndp_demand = row_series(57)   # GWh/yr
tyndp_trade  = row_series(59)   # GWh/yr
tyndp_lmp    = row_series(218)  # EUR/MWh

print("TYNDP DE00 by category:")
for cat in CAT_ORDER:
    if cat in tyndp_gen_twh.columns:
        v = tyndp_gen_twh.at["DE00", cat]
        if v > 0.1:
            print(f"  {cat:<22} {v:7.1f} TWh")
print(f"  {'Demand':<22} {tyndp_demand['DE00']/1000:7.1f} TWh")
print(f"  {'Net export':<22} {tyndp_trade['DE00']/1000:+7.1f} TWh")
print(f"  {'LMP':<22} {tyndp_lmp['DE00']:7.2f} EUR/MWh")

print(f"\nEurope-wide totals (common buses):")
for cat in CAT_ORDER:
    if cat in tyndp_gen_twh.columns:
        v = tyndp_gen_twh[cat].sum()
        if v > 1:
            print(f"  {cat:<22} {v:8.1f} TWh")
# Out:
# TYNDP DE00 by category:
#   Gas                       54.3 TWh
#   Oil                        0.8 TWh
#   Other Thermal              0.6 TWh
#   Hydro Reservoir            0.7 TWh
#   Hydro RoR                 16.7 TWh
#   Hydro PHS                 18.8 TWh
#   Wind Onshore             239.6 TWh
#   Wind Offshore            130.3 TWh
#   Solar PV                 190.7 TWh
#   Battery                    2.5 TWh
#   Hydrogen                   5.8 TWh
#   Other RES                 70.2 TWh
#   DSR                       44.5 TWh
#   Demand                   714.1 TWh
#   Net export               -14.9 TWh
#   LMP                      61.42 EUR/MWh
#
# Europe-wide totals (common buses):
#   Nuclear                   601.6 TWh
#   Lignite                    15.1 TWh
#   Coal                       28.7 TWh
#   Gas                       371.5 TWh
#   Oil                         2.9 TWh
#   Other Thermal             112.0 TWh
#   Hydro Reservoir           334.5 TWh
# ...

# %%
# Compute PyPSA model quantities: generation, LMP, net trade balance

gen_annual  = n.generators_t.p.sum()
su_dispatch = n.storage_units_t.p.clip(lower=0).sum()  # discharge only

# Generators
model_gen_data = {}
for gen_id, g in n.generators.iterrows():
    cat = carrier_to_cat(g["carrier"])
    if cat is None:
        continue  # skip slack + unknowns
    bus = g["bus"]
    mwh = float(gen_annual.get(gen_id, 0.0))
    model_gen_data.setdefault(bus, {})
    model_gen_data[bus][cat] = model_gen_data[bus].get(cat, 0.0) + mwh

# Storage units (discharge only)
for su_id, s in n.storage_units.iterrows():
    cat = carrier_to_cat(s["carrier"])
    if cat is None:
        continue
    bus = s["bus"]
    mwh = float(su_dispatch.get(su_id, 0.0))
    model_gen_data.setdefault(bus, {})
    model_gen_data[bus][cat] = model_gen_data[bus].get(cat, 0.0) + mwh

model_gen = pd.DataFrame(model_gen_data).T.fillna(0)
model_gen = model_gen.reindex(columns=[c for c in CAT_ORDER if c in model_gen.columns], fill_value=0)
model_gen_twh = model_gen / 1e6  # MWh → TWh  (model values are in MWh)

# Annual average LMP
model_lmp_annual = n.buses_t.marginal_price.mean()

# Net exports via AC lines + DC links (MWh → TWh)
def compute_net_exports(n):
    net = pd.Series(0.0, index=n.buses.index)
    if not n.lines_t.p0.empty:
        p0 = n.lines_t.p0
        for line in n.lines.index:
            if line not in p0.columns: continue
            b0, b1 = n.lines.at[line, "bus0"], n.lines.at[line, "bus1"]
            flow = float(p0[line].sum())
            if b0 in net.index: net[b0] += flow
            if b1 in net.index: net[b1] -= flow
    if not n.links_t.p0.empty:
        p0l, p1l = n.links_t.p0, n.links_t.p1
        for link in n.links.index:
            if link not in p0l.columns: continue
            b0, b1 = n.links.at[link, "bus0"], n.links.at[link, "bus1"]
            if b0 in net.index: net[b0] += float(p0l[link].sum())
            if b1 in net.index: net[b1] += float(p1l[link].sum())
    return net / 1e6  # → TWh

model_net_export_twh = compute_net_exports(n)

print("Model DE00 by category:")
for cat in CAT_ORDER:
    if cat in model_gen_twh.columns:
        v = model_gen_twh.at["DE00", cat] if "DE00" in model_gen_twh.index else 0
        if v > 0.1:
            print(f"  {cat:<22} {v:7.1f} TWh")
print(f"\n  LMP:  {model_lmp_annual.get('DE00', np.nan):.2f} EUR/MWh")
print(f"  TYNDP:{tyndp_lmp.get('DE00', np.nan):.2f} EUR/MWh")

print(f"\nModel Europe-wide:")
for cat in CAT_ORDER:
    if cat in model_gen_twh.columns:
        v = model_gen_twh[cat].sum()
        if v > 0.5:
            print(f"  {cat:<22} {v:8.1f} TWh")
# Out:
# Model DE00 by category:
#   Gas                       57.2 TWh
#   Other Thermal             14.5 TWh
#   Hydro Reservoir            0.6 TWh
#   Hydro RoR                 16.8 TWh
#   Hydro PHS                 20.9 TWh
#   Wind Onshore             219.4 TWh
#   Wind Offshore            128.5 TWh
#   Solar PV                 189.7 TWh
#   Battery                    2.6 TWh
#   Hydrogen                   0.7 TWh
#   Other RES                 48.7 TWh
#   DSR                       42.3 TWh
#
#   LMP:  61.74 EUR/MWh
#   TYNDP:61.42 EUR/MWh
#
# Model Europe-wide:
#   Nuclear                   602.2 TWh
#   Coal                        3.5 TWh
#   Gas                       347.5 TWh
#   Oil                         0.8 TWh
#   Other Thermal              64.5 TWh
#   Hydro Reservoir           302.1 TWh
#   Hydro RoR                 201.6 TWh
#   Hydro PHS                 112.1 TWh
#   Wind Onshore              838.3 TWh
#   Wind Offshore             627.4 TWh
# ...

# %% [markdown]
# ## Section 0 — Installed Capacity & Full Load Hours
#
# **Installed capacity** (MW → GW) and **equivalent full load hours** (FLH = annual generation / installed capacity) are compared first — before generation — to confirm that both models share the same capacity assumptions.
#
# - Capacity: TYNDP `Yearly Outputs` rows 166–215 [MW]; model `generators.p_nom` + `storage_units.p_nom`
# - FLH: derived as `gen_GWh × 1000 / cap_MW` in both cases (more consistent than reading the raw FLH rows, which are per sub-technology vintage)
# - *Total income [M€] is available in TYNDP (rows 116–165) but is not compared: Plexos MILP market revenue ≠ PyPSA LP shadow-price revenue — comparison would be methodologically misleading.*

# %%
# Section 0: Installed capacity + full load hours

# ── TYNDP installed capacity (rows 166–215, MW) ───────────────────────────────
cap_data_t = {bus: {} for bus in bus_col_idx}
for row_i in range(166, 216):
    tech = str(raw.iloc[row_i, 1]).strip()
    if tech == "nan":
        continue
    cat = classify_tyndp(tech)
    if cat is None:
        continue
    for bus, ci in bus_col_idx.items():
        try:
            val = float(raw.iloc[row_i, ci])
        except (ValueError, TypeError):
            val = 0.0
        cap_data_t[bus][cat] = cap_data_t[bus].get(cat, 0.0) + val

tyndp_cap = pd.DataFrame(cap_data_t).T.fillna(0)
tyndp_cap = tyndp_cap.reindex(columns=[c for c in CAT_ORDER if c in tyndp_cap.columns], fill_value=0)
tyndp_cap_gw = tyndp_cap / 1000  # MW → GW

# Correct TYNDP DSR capacity: TYNDP XLSX reports total DSR across all CYs,
# but our model filters DSR to the specific climate year (CY2009).
# Use filtered DSR from dsr_pemmdb.csv for fair comparison.
_dsr = pd.read_csv("../data/open-tyndp/dsr_pemmdb.csv")
_dsr_cy = _dsr[(_dsr["Climate year start"] <= 2009) & (_dsr["Climate year end"] >= 2009)]
_dsr_per_bus = _dsr_cy.groupby("node")["Capacity"].sum()
# Remap UK00 -> GB00
_dsr_per_bus.index = _dsr_per_bus.index.map(lambda x: "GB00" if x == "UK00" else x)
if "DSR" in tyndp_cap.columns:
    for bus in tyndp_cap.index:
        tyndp_cap.loc[bus, "DSR"] = _dsr_per_bus.get(bus, 0.0)
    tyndp_cap_gw = tyndp_cap / 1000

# ── Model installed capacity (p_nom, MW) ──────────────────────────────────────
model_cap_data = {}
for gen_id, g in n.generators.iterrows():
    cat = carrier_to_cat(g["carrier"])
    if cat is None:
        continue
    bus = g["bus"]
    model_cap_data.setdefault(bus, {})
    model_cap_data[bus][cat] = model_cap_data[bus].get(cat, 0.0) + float(g["p_nom"])

for su_id, s in n.storage_units.iterrows():
    cat = carrier_to_cat(s["carrier"])
    if cat is None:
        continue
    bus = s["bus"]
    model_cap_data.setdefault(bus, {})
    model_cap_data[bus][cat] = model_cap_data[bus].get(cat, 0.0) + float(s["p_nom"])

model_cap = pd.DataFrame(model_cap_data).T.fillna(0)
model_cap = model_cap.reindex(columns=[c for c in CAT_ORDER if c in model_cap.columns], fill_value=0)
model_cap_gw = model_cap / 1000  # MW → GW

# ── Europe-wide totals + diff ──────────────────────────────────────────────────
all_cap_cats = [c for c in CAT_ORDER if c in tyndp_cap_gw.columns or c in model_cap_gw.columns]
tyndp_cap_eu = pd.Series({c: tyndp_cap_gw[c].sum() if c in tyndp_cap_gw.columns else 0.0 for c in all_cap_cats})
model_cap_eu = pd.Series({c: model_cap_gw[c].sum() if c in model_cap_gw.columns else 0.0 for c in all_cap_cats})
caps_show = [c for c in all_cap_cats if tyndp_cap_eu[c] > 0.1 or model_cap_eu[c] > 0.1]

total_t_cap   = tyndp_cap_eu[caps_show].sum()
total_m_cap   = model_cap_eu[caps_show].sum()
diff_cap      = total_m_cap - total_t_cap
pct_diff_cap  = 100 * diff_cap / total_t_cap
cap_color     = "#c0392b" if abs(pct_diff_cap) > 5 else "#27ae60"

fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Left: stacked bar
ax = axes[0]
x = np.arange(2)
bottom = np.zeros(2)
for cat in caps_show:
    heights = np.array([tyndp_cap_eu[cat], model_cap_eu[cat]])
    color = CAT_COLORS.get(cat, "#9E9E9E")
    ax.bar(x, heights, bottom=bottom, color=color, label=cat, width=0.5,
           edgecolor="white", linewidth=0.4)
    for xi, (h, b) in enumerate(zip(heights, bottom)):
        if h > 10:
            ax.text(xi, b + h / 2, f"{h:.0f}", ha="center", va="center",
                    fontsize=7, color="white", fontweight="bold")
    bottom += heights

ax.set_xticks(x)
ax.set_xticklabels(["TYNDP 2030 NT\nPlexos CY2009", "PyPSA Model\nCY2009"], fontsize=12)
ax.set_ylabel("Installed capacity [GW]")
ax.set_title(
    f"Europe-wide Installed Capacity — TYNDP vs Model\n"
    f"Total diff: {diff_cap:+.0f} GW  ({pct_diff_cap:+.1f}%)",
    fontsize=11, fontweight="bold", color=cap_color
)
ax.legend(loc="upper right", fontsize=8, ncol=2, framealpha=0.85)
ax.grid(axis="y", alpha=0.3)

# Right: per-category diff bar
ax2 = axes[1]
diffs_cap = [(c, model_cap_eu[c] - tyndp_cap_eu[c]) for c in caps_show]
diffs_cap.sort(key=lambda x: x[1])
cats_c, vals_c = zip(*diffs_cap)
colors_c = [CAT_COLORS.get(c, "#9E9E9E") for c in cats_c]
ax2.barh(range(len(cats_c)), vals_c, color=colors_c, edgecolor="white", linewidth=0.3)
ax2.axvline(0, color="black", linewidth=0.8)
ax2.set_yticks(range(len(cats_c)))
ax2.set_yticklabels(cats_c, fontsize=9)
ax2.set_xlabel("Model − TYNDP [GW]")
ax2.set_title("Capacity Difference by Category\n(Model − TYNDP)", fontsize=11, fontweight="bold")
ax2.grid(axis="x", alpha=0.3)
for i, v in enumerate(vals_c):
    if abs(v) > 1:
        ax2.text(v + (0.3 if v >= 0 else -0.3), i, f"{v:+.1f}", va="center",
                 fontsize=8, ha="left" if v >= 0 else "right")

plt.tight_layout()
plt.show()

# Capacity table
print(f"\n{'Category':<22} {'TYNDP GW':>9} {'Model GW':>9} {'Diff GW':>9} {'Diff%':>7}")
print("-" * 58)
for cat in caps_show:
    t, m = tyndp_cap_eu[cat], model_cap_eu[cat]
    d = m - t
    pct = 100 * d / t if t > 0 else np.nan
    flag = "  !" if not np.isnan(pct) and abs(pct) > 15 else ""
    print(f"{cat:<22} {t:9.1f} {m:9.1f} {d:+9.1f} {pct:+6.1f}%{flag}")
print(f"{'TOTAL':<22} {total_t_cap:9.1f} {total_m_cap:9.1f} {diff_cap:+9.1f} {pct_diff_cap:+6.1f}%")
# Out:
# Category                TYNDP GW  Model GW   Diff GW   Diff%
# ----------------------------------------------------------
# Nuclear                    101.8     101.8      +0.0   +0.0%
# Lignite                     21.5      21.5      -0.0   -0.0%
# Coal                        16.7      16.7      +0.0   +0.0%
# Gas                        209.8     206.1      -3.7   -1.8%
# Oil                          7.2       7.2      -0.0   -0.0%
# Other Thermal               47.2      47.3      +0.1   +0.1%
# Hydro Reservoir            113.0     113.0      -0.0   -0.0%
# Hydro RoR                   58.1      58.1      -0.0   -0.0%
# Hydro PHS                   61.9      61.9      +0.0   +0.0%
# Wind Onshore               399.0     399.0      -0.0   -0.0%
# Wind Offshore              149.1     156.2      +7.1   +4.8%
# Solar PV                   693.0     693.0      +0.0   +0.0%
# Battery                     62.3      62.3      -0.0   -0.0%
# ...

# %%
# Section 0 (cont.): Full load hours — FLH = gen_GWh * 1000 / cap_MW  (Europe-wide weighted average)

# Build Europe-wide FLH per category
flh_cats = [c for c in CAT_ORDER
            if tyndp_cap_eu.get(c, 0) > 0.5 and tyndp_cap_eu.get(c, 0) > 0]

tyndp_flh_eu = {}
model_flh_eu = {}
for cat in flh_cats:
    t_gen_gwh = tyndp_gen_twh[cat].sum() * 1000 if cat in tyndp_gen_twh.columns else 0.0  # GWh
    t_cap_mw  = tyndp_cap[cat].sum() if cat in tyndp_cap.columns else 0.0                  # MW
    tyndp_flh_eu[cat] = t_gen_gwh * 1000 / t_cap_mw if t_cap_mw > 0 else np.nan          # MWh/MW = h

    m_gen_gwh = model_gen_twh[cat].sum() * 1000 if cat in model_gen_twh.columns else 0.0  # GWh
    m_cap_mw  = model_cap[cat].sum() if cat in model_cap.columns else 0.0                  # MW
    model_flh_eu[cat] = m_gen_gwh * 1000 / m_cap_mw if m_cap_mw > 0 else np.nan

flh_cats_show = [c for c in flh_cats
                 if not np.isnan(tyndp_flh_eu.get(c, np.nan))
                 and not np.isnan(model_flh_eu.get(c, np.nan))]

# Sort by TYNDP FLH descending
flh_cats_show.sort(key=lambda c: tyndp_flh_eu[c], reverse=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Grouped bar chart
x = np.arange(len(flh_cats_show))
w = 0.35
t_vals = [tyndp_flh_eu[c] for c in flh_cats_show]
m_vals = [model_flh_eu[c] for c in flh_cats_show]

bars_t = ax1.bar(x - w/2, t_vals, width=w, color="#F57F17", alpha=0.85, label="TYNDP Plexos")
bars_m = ax1.bar(x + w/2, m_vals, width=w, color="#1565C0", alpha=0.85, label="PyPSA Model")
ax1.set_xticks(x)
ax1.set_xticklabels(flh_cats_show, rotation=40, ha="right", fontsize=9)
ax1.set_ylabel("Equivalent full load hours [h/yr]")
ax1.set_title("Europe-wide Average Full Load Hours\nby Technology Category", fontsize=11, fontweight="bold")
ax1.axhline(8760, color="grey", linestyle=":", linewidth=0.8, alpha=0.6, label="8760 h (max)")
ax1.legend(fontsize=9)
ax1.grid(axis="y", alpha=0.3)

# Diff bar — (Model - TYNDP) sorted
diffs_flh = {c: model_flh_eu[c] - tyndp_flh_eu[c] for c in flh_cats_show}
sorted_flh = sorted(diffs_flh.items(), key=lambda x: x[1])
cats_f, vals_f = zip(*sorted_flh)
colors_f = [CAT_COLORS.get(c, "#9E9E9E") for c in cats_f]
ax2.barh(range(len(cats_f)), vals_f, color=colors_f, edgecolor="white", linewidth=0.3)
ax2.axvline(0, color="black", linewidth=0.8)
ax2.set_yticks(range(len(cats_f)))
ax2.set_yticklabels(cats_f, fontsize=9)
ax2.set_xlabel("Model − TYNDP [h/yr]")
ax2.set_title("FLH Difference by Category\n(positive = model dispatches more)", fontsize=11, fontweight="bold")
ax2.grid(axis="x", alpha=0.3)
for i, v in enumerate(vals_f):
    if abs(v) > 50:
        ax2.text(v + (10 if v >= 0 else -10), i, f"{v:+.0f}h", va="center",
                 fontsize=8, ha="left" if v >= 0 else "right")

plt.tight_layout()
plt.show()

# FLH table
print(f"\n{'Category':<22} {'TYNDP h':>8} {'Model h':>8} {'Diff h':>8} {'Note'}")
print("-" * 60)
for cat in flh_cats_show:
    t = tyndp_flh_eu[cat]
    m = model_flh_eu[cat]
    d = m - t
    pct = 100 * d / t if t > 0 else np.nan
    flag = "  !" if abs(pct) > 20 else ""
    print(f"{cat:<22} {t:8.0f} {m:8.0f} {d:+8.0f}  ({pct:+.1f}%){flag}")
# Out:
# Category                TYNDP h  Model h   Diff h Note
# ------------------------------------------------------------
# Nuclear                    5910     5916       +6  (+0.1%)
# Other RES                  5162     3024    -2138  (-41.4%)  !
# Wind Offshore              4122     4016     -106  (-2.6%)
# Hydro RoR                  3428     3473      +45  (+1.3%)
# Hydro Reservoir            2959     2672     -286  (-9.7%)
# Wind Onshore               2421     2101     -320  (-13.2%)
# Other Thermal              2373     1364    -1008  (-42.5%)  !
# Gas                        1771     1686      -85  (-4.8%)
# Coal                       1715      210    -1505  (-87.8%)  !
# Hydro PHS                  1679     1812     +133  (+7.9%)
# Solar PV                   1143     1180      +37  (+3.2%)
# Battery                     964      815     -149  (-15.5%)
# DSR                         808      789      -19  (-2.4%)
# Lignite                     702        4     -699  (-99.5%)  !
# ...

# %% [markdown]
# ## Section 1 — Annual Generation Mix (Europe-wide)
#
# Stacked bar charts: total annual generation by technology category across all **55 common buses**.
# Units: TWh/year. TYNDP values from `Yearly Outputs` sheet (GWh/yr); model from dispatch optimisation (MWh/yr).
#
# **Note on total generation difference (~329 TWh):**
# The TYNDP Plexos total is systematically higher for two reasons unrelated to generation technology dispatch:
# 1. **Electrolyser load (~238 TWh)** — Plexos models electrolysers as an explicit electricity load producing hydrogen. In the PyPSA model, H₂-CCGT and H₂ fuel cell generators use hydrogen as an external fuel input; no electrolyser is modelled, so no additional electricity generation is needed to produce it.
# 2. **Network losses (~82 TWh)** — Plexos uses a full AC power flow with resistive losses. PyPSA uses a lossless LP approximation (~25 TWh losses vs ~107 TWh in Plexos).
#
# Native consumer demand matches within **0.3%** (3 947 vs 3 936 TWh). The per-category comparison below is therefore meaningful despite the total gap.

# %%
# Section 1: Europe-wide annual generation stacked bars — TYNDP vs Model

all_cats = [c for c in CAT_ORDER if c in tyndp_gen_twh.columns or c in model_gen_twh.columns]
tyndp_eu = pd.Series({c: tyndp_gen_twh[c].sum() if c in tyndp_gen_twh.columns else 0.0 for c in all_cats})
model_eu = pd.Series({c: model_gen_twh[c].sum() if c in model_gen_twh.columns else 0.0 for c in all_cats})
cats_show = [c for c in all_cats if tyndp_eu[c] > 0.5 or model_eu[c] > 0.5]

total_t, total_m = tyndp_eu[cats_show].sum(), model_eu[cats_show].sum()
diff_eu  = total_m - total_t
pct_eu   = 100 * diff_eu / total_t
diff_color = "#c0392b" if abs(pct_eu) > 5 else "#27ae60"

fig, ax = plt.subplots(figsize=(10, 7))
x = np.arange(2)
w = 0.5
bottom = np.zeros(2)
for cat in cats_show:
    heights = np.array([tyndp_eu[cat], model_eu[cat]])
    color = CAT_COLORS.get(cat, "#9E9E9E")
    ax.bar(x, heights, bottom=bottom, color=color, label=cat, width=w, edgecolor="white", linewidth=0.4)
    for xi, (h, b) in enumerate(zip(heights, bottom)):
        if h > 15:
            ax.text(xi, b + h / 2, f"{h:.0f}", ha="center", va="center",
                    fontsize=7, color="white", fontweight="bold")
    bottom += heights

ax.set_xticks(x)
ax.set_xticklabels(["TYNDP 2030 NT\nPlexos CY2009", "PyPSA Model\nCY2009"], fontsize=12)
ax.set_ylabel("Annual generation [TWh]", fontsize=11)
ax.set_title(
    f"Europe-wide Annual Generation Mix — TYNDP vs Model\n"
    f"Total diff: {diff_eu:+.0f} TWh  ({pct_eu:+.1f}%)",
    fontsize=12, fontweight="bold", color=diff_color
)
ax.legend(loc="upper right", fontsize=8, ncol=2, framealpha=0.85)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda v, _: f"{v:.0f}"))
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# Comparison table
print(f"\n{'Category':<22} {'TYNDP':>8} {'Model':>8} {'Diff':>8} {'Diff%':>7}")
print("-" * 57)
for cat in cats_show:
    t, m = tyndp_eu[cat], model_eu[cat]
    d = m - t
    pct = 100 * d / t if t > 0 else np.nan
    flag = "  !" if not np.isnan(pct) and abs(pct) > 20 else ""
    print(f"{cat:<22} {t:8.1f} {m:8.1f} {d:+8.1f} {pct:+6.1f}%{flag}")
print(f"{'TOTAL':<22} {total_t:8.1f} {total_m:8.1f} {diff_eu:+8.1f} {pct_eu:+6.1f}%")
# Out:
# Category                  TYNDP    Model     Diff   Diff%
# ---------------------------------------------------------
# Nuclear                   601.6    602.2     +0.6   +0.1%
# Lignite                    15.1      0.1    -15.0  -99.5%  !
# Coal                       28.7      3.5    -25.2  -87.8%  !
# Gas                       371.5    347.5    -24.0   -6.5%
# Oil                         2.9      0.8     -2.1  -71.4%  !
# Other Thermal             112.0     64.5    -47.5  -42.4%  !
# Hydro Reservoir           334.5    302.1    -32.4   -9.7%
# Hydro RoR                 199.0    201.6     +2.6   +1.3%
# Hydro PHS                 103.8    112.1     +8.3   +7.9%
# Wind Onshore              966.1    838.3   -127.7  -13.2%
# Wind Offshore             614.7    627.4    +12.7   +2.1%
# Solar PV                  792.4    817.9    +25.5   +3.2%
# Battery                    60.1     50.8     -9.3  -15.5%
# Hydrogen                    6.5      0.9     -5.6  -85.9%  !
# ...

# %% [markdown]
# ## Section 2 — Per-Bus Generation Comparison (Heatmap)
#
# Relative difference `(Model − TYNDP) / TYNDP × 100%` by bus and technology category.
# - Green = model higher than TYNDP | Red = model lower
# - White / grey = TYNDP has < 1 TWh in that category (comparison not meaningful)
# - Buses sorted by total TYNDP generation (descending)

# %%
# Section 2: Per-bus generation heatmap — (Model - TYNDP) / TYNDP [%]

common_buses = sorted(set(tyndp_gen_twh.index) & set(model_gen_twh.index))
cats_hmap = [c for c in CAT_ORDER if c in tyndp_gen_twh.columns and c in model_gen_twh.columns]

# Build relative diff matrix
diff_rel = pd.DataFrame(np.nan, index=common_buses, columns=cats_hmap)
for bus in common_buses:
    for cat in cats_hmap:
        t = tyndp_gen_twh.at[bus, cat] if bus in tyndp_gen_twh.index else 0.0
        m = model_gen_twh.at[bus, cat] if bus in model_gen_twh.index else 0.0
        if t >= 1.0:  # only show where TYNDP has significant generation
            diff_rel.at[bus, cat] = 100.0 * (m - t) / t

# Sort buses by total TYNDP generation
bus_order = tyndp_gen_twh.reindex(common_buses).sum(axis=1).sort_values(ascending=False).index
diff_rel = diff_rel.loc[bus_order]

# Drop all-NaN columns
cats_show_h = [c for c in cats_hmap if diff_rel[c].notna().any()]
diff_arr = diff_rel[cats_show_h].values.astype(float)

fig_h = max(8, len(common_buses) * 0.30)
fig_w = max(10, len(cats_show_h) * 1.0)
fig, ax = plt.subplots(figsize=(fig_w, fig_h))

vmax = 35
im = ax.imshow(diff_arr, aspect="auto", cmap="RdYlGn", vmin=-vmax, vmax=vmax)
cbar = plt.colorbar(im, ax=ax, fraction=0.02, pad=0.02)
cbar.set_label("(Model − TYNDP) / TYNDP  [%]", fontsize=9)

ax.set_xticks(range(len(cats_show_h)))
ax.set_xticklabels(cats_show_h, rotation=40, ha="right", fontsize=9)
ax.set_yticks(range(len(bus_order)))
ax.set_yticklabels(bus_order, fontsize=7)
ax.set_title("Per-Bus Generation — Relative Difference: Model vs TYNDP [%]\n"
             "(TYNDP < 1 TWh shown as grey)", fontsize=11, fontweight="bold")
plt.tight_layout()
plt.show()

# Also print buses with largest absolute differences (top 10)
abs_diff = diff_rel.abs().mean(axis=1).sort_values(ascending=False)
print("Buses with largest average absolute generation deviation:")
for bus in abs_diff.head(10).index:
    print(f"  {bus}: avg |diff| = {abs_diff[bus]:.1f}%")
# Out:
# Buses with largest average absolute generation deviation:
#   DKE1: avg |diff| = 85.0%
#   HR00: avg |diff| = 42.8%
#   ITSI: avg |diff| = 40.6%
#   DKW1: avg |diff| = 40.0%
#   GBNI: avg |diff| = 39.7%
#   FI00: avg |diff| = 39.6%
#   ES00: avg |diff| = 39.6%
#   ITS1: avg |diff| = 38.6%
#   IE00: avg |diff| = 37.0%
#   PT00: avg |diff| = 36.7%

# %%
# Section 2 (cont.): Weighted heatmap
# Each cell = (model_gen - tyndp_gen) / tyndp_total_for_bus × 100 %
# Interpretation: contribution of each category's mismatch to the total
# generation gap for that bus.  A cell of +5 % means this category alone
# explains 5 % of the bus's total TYNDP generation as a surplus in the model.
# Grey = TYNDP has < 1 TWh for that category (no meaningful comparison).

common_buses_w = sorted(set(tyndp_gen_twh.index) & set(model_gen_twh.index))
cats_hmap_w    = [c for c in CAT_ORDER if c in tyndp_gen_twh.columns and c in model_gen_twh.columns]

tyndp_bus_total = tyndp_gen_twh.reindex(common_buses_w).sum(axis=1)  # total TYNDP gen per bus [TWh]

diff_weighted = pd.DataFrame(np.nan, index=common_buses_w, columns=cats_hmap_w)
for bus in common_buses_w:
    bus_total = tyndp_bus_total[bus]
    if bus_total < 1.0:
        continue
    for cat in cats_hmap_w:
        t = tyndp_gen_twh.at[bus, cat] if bus in tyndp_gen_twh.index else 0.0
        m = model_gen_twh.at[bus, cat] if bus in model_gen_twh.index else 0.0
        if t >= 1.0:  # only show where TYNDP has significant generation
            diff_weighted.at[bus, cat] = 100.0 * (m - t) / bus_total

# Sort buses same as original heatmap (by total TYNDP gen)
diff_weighted = diff_weighted.loc[bus_order]
cats_show_w = [c for c in cats_hmap_w if diff_weighted[c].notna().any()]
diff_arr_w   = diff_weighted[cats_show_w].values.astype(float)

fig_h2 = max(8, len(common_buses_w) * 0.30)
fig_w2 = max(10, len(cats_show_w) * 1.0)
fig, ax = plt.subplots(figsize=(fig_w2, fig_h2))

vmax_w = 15
im2 = ax.imshow(diff_arr_w, aspect="auto", cmap="RdYlGn", vmin=-vmax_w, vmax=vmax_w)
cbar2 = plt.colorbar(im2, ax=ax, fraction=0.02, pad=0.02)
cbar2.set_label("(Model − TYNDP) / TYNDP_total_bus  [% of bus total gen]", fontsize=9)

ax.set_xticks(range(len(cats_show_w)))
ax.set_xticklabels(cats_show_w, rotation=40, ha="right", fontsize=9)
ax.set_yticks(range(len(bus_order)))
ax.set_yticklabels(bus_order, fontsize=7)
ax.set_title(
    "Per-Bus Generation — Weighted Contribution of Mismatch\n"
    "(Model − TYNDP) / TYNDP bus total  [%]  |  grey = TYNDP < 1 TWh",
    fontsize=11, fontweight="bold"
)
plt.tight_layout()
plt.show()

# Print buses where any single category explains > 5 % of total gen
print("Buses where a single category mismatch exceeds ±5 % of total bus generation:")
for bus in bus_order:
    row = diff_weighted.loc[bus]
    big = row[row.abs() > 5].dropna()
    if len(big):
        parts = ", ".join(f"{cat}: {v:+.1f}%" for cat, v in big.items())
        print(f"  {bus}: {parts}")
# Out:
# Buses where a single category mismatch exceeds ±5 % of total bus generation:
#   GB00: Wind Onshore: -7.4%
#   ES00: Gas: -6.6%, Wind Onshore: -6.7%
#   FI00: Other RES: -6.4%
#   NOS0: Hydro Reservoir: -6.2%
#   SE03: Other RES: -12.9%
#   PT00: Wind Onshore: -6.2%, Other RES: -7.0%
#   RO00: Gas: -12.6%
#   GR00: Gas: -15.2%
#   IE00: Gas: -5.2%, Wind Onshore: -20.4%
#   ITS1: Gas: -9.4%, Solar PV: +7.4%
#   SE02: Hydro Reservoir: -6.0%
#   CZ00: Gas: +7.3%
#   HU00: Gas: +13.1%
#   ITCS: Gas: +7.2%
#   DKW1: Coal: -6.7%, Gas: -6.1%, Wind Onshore: -5.5%
#   RS00: Lignite: -29.9%
#   ITSI: Gas: -7.8%, Other Thermal: -7.4%, Solar PV: +14.8%
#   BG00: Gas: +8.0%
#   LT00: Wind Onshore: -9.7%
#   NOM1: Hydro Reservoir: -5.7%
#   SE01: Hydro Reservoir: -6.5%
#   NON1: Other Thermal: -6.2%, Hydro Reservoir: -7.1%
#   DKE1: Coal: -23.2%, Wind Onshore: -7.8%, Wind Offshore: +60.2%
#   ITSA: Solar PV: +5.3%
#   HR00: Gas: +11.3%
#   ITCA: Gas: -36.5%
# ...

# %% [markdown]
# ## Section 3 — DE00 Monthly Generation Detail
#
# **Top:** Monthly generation by category — PyPSA model (Jan–Dec stacked bars).
# **Bottom:** Monthly generation by category — TYNDP 2030 NT Plexos CY2009 (from `Hourly Market Data` sheet, hourly MW values resampled to monthly TWh).
# Both panels use the same colour scheme for direct visual comparison.

# %%
# Section 3: DE00 generation — model monthly (top) + TYNDP monthly (bottom)

BUS = FOCUS_BUS  # "DE00"

# ── 1. Model monthly generation ──────────────────────────────────────────────
model_de_monthly = {}
for gen_id, g in n.generators.iterrows():
    if g["bus"] != BUS or gen_id not in n.generators_t.p.columns: continue
    cat = carrier_to_cat(g["carrier"])
    if cat is None: continue
    ts = n.generators_t.p[gen_id]
    model_de_monthly.setdefault(cat, np.zeros(12))
    for mo in range(12):
        model_de_monthly[cat][mo] += float(ts[ts.index.month == mo + 1].sum()) / 1e6

for su_id, s in n.storage_units.iterrows():
    if s["bus"] != BUS or su_id not in n.storage_units_t.p.columns: continue
    cat = carrier_to_cat(s["carrier"])
    if cat is None: continue
    ts = n.storage_units_t.p[su_id].clip(lower=0)
    model_de_monthly.setdefault(cat, np.zeros(12))
    for mo in range(12):
        model_de_monthly[cat][mo] += float(ts[ts.index.month == mo + 1].sum()) / 1e6

cats_de_model = [c for c in CAT_ORDER if c in model_de_monthly and max(model_de_monthly[c]) > 0.05]

# ── 2. TYNDP monthly generation from Hourly Market Data ──────────────────────
meta_hmd = pd.read_excel(XLSX, sheet_name="Hourly Market Data",
                         header=None, nrows=13, engine="openpyxl")
row_cat_h  = meta_hmd.iloc[10].astype(str)
row_zone_h = meta_hmd.iloc[11].astype(str).str.strip().replace("UK00", "GB00")

def classify_tyndp_strict(name):
    """Like classify_tyndp but returns None when no key matched (no fallback to Other Thermal)."""
    nl = name.lower().strip()
    best_key, best_cat = "", None
    for key, cat in TYNDP_CAT.items():
        if key in nl and len(key) > len(best_key):
            best_key, best_cat = key, cat
    return best_cat

# Collect generation columns for BUS (skip demand, marginal price, curtailment, charging)
bus_gen_cols = {}  # col_idx → category
for ci in range(2, meta_hmd.shape[1]):
    if row_zone_h[ci] != BUS:
        continue
    cat = classify_tyndp_strict(row_cat_h[ci])
    if cat is None:
        continue
    bus_gen_cols[ci] = cat

print(f"Found {len(bus_gen_cols)} generation columns for {BUS} in Hourly Market Data")
for ci, cat in sorted(bus_gen_cols.items()):
    print(f"  col {ci:4d}: {row_cat_h[ci]:<50s} → {cat}")

# Read hourly values for those columns only
usecols_hmd = [1] + sorted(bus_gen_cols.keys())
hmd_raw = pd.read_excel(XLSX, sheet_name="Hourly Market Data",
                        header=None, skiprows=13, usecols=usecols_hmd, engine="openpyxl")
hmd_raw.columns = ["ts_str"] + [f"c{ci}" for ci in sorted(bus_gen_cols.keys())]
hmd_raw = hmd_raw.dropna(subset=["ts_str"])

MONTH_MAP = {"JAN":1,"FEB":2,"MAR":3,"APR":4,"MAY":5,"JUN":6,
             "JUL":7,"AUG":8,"SEP":9,"OCT":10,"NOV":11,"DEC":12}

def parse_hmd_ts(s):
    s = str(s).strip()
    try:
        day = int(s[:2])
        mon = MONTH_MAP.get(s[2:5].upper())
        hour = int(s[5:7])
        if mon is None: return pd.NaT
        return pd.Timestamp(year=2030, month=mon, day=day, hour=hour)
    except Exception:
        return pd.NaT

hmd_raw["timestamp"] = hmd_raw["ts_str"].apply(parse_hmd_ts)
hmd_raw = hmd_raw.dropna(subset=["timestamp"]).set_index("timestamp")

# Aggregate MW × 1 h = MWh per category per month → TWh
tyndp_de_monthly = {}
for ci, cat in bus_gen_cols.items():
    col = f"c{ci}"
    if col not in hmd_raw.columns: continue
    series = pd.to_numeric(hmd_raw[col], errors="coerce").fillna(0).clip(lower=0)
    tyndp_de_monthly.setdefault(cat, np.zeros(12))
    for mo in range(12):
        tyndp_de_monthly[cat][mo] += float(series[series.index.month == mo + 1].sum()) / 1e6

cats_de_tyndp = [c for c in CAT_ORDER if c in tyndp_de_monthly and max(tyndp_de_monthly[c]) > 0.05]

# Sanity check vs Yearly Outputs annual totals
print(f"\n{BUS} annual check — Hourly Market Data vs Yearly Outputs:")
print(f"  {'Category':<22} {'HMD TWh':>9} {'YO TWh':>9} {'Diff%':>7}")
print("  " + "-" * 50)
for cat in cats_de_tyndp:
    hmd_yr = sum(tyndp_de_monthly[cat])
    yo_yr  = float(tyndp_gen_twh.at[BUS, cat]) if cat in tyndp_gen_twh.columns else 0.0
    diff_pct = 100 * (hmd_yr - yo_yr) / yo_yr if yo_yr > 0 else np.nan
    print(f"  {cat:<22} {hmd_yr:9.1f} {yo_yr:9.1f} {diff_pct:+6.1f}%")

# ── 3. Plot ───────────────────────────────────────────────────────────────────
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 12))
x = np.arange(12)

# --- TOP: Model monthly ---
bottom = np.zeros(12)
for cat in cats_de_model:
    h = model_de_monthly[cat]
    ax1.bar(x, h, bottom=bottom, color=CAT_COLORS.get(cat, "#9E9E9E"),
            label=cat, edgecolor="white", linewidth=0.3)
    bottom += h
ax1.set_xticks(x)
ax1.set_xticklabels(MONTH_NAMES)
ax1.set_ylabel("Generation [TWh/month]")
ax1.set_title(f"{BUS} — PyPSA Model Monthly Generation", fontweight="bold")
ax1.legend(fontsize=8, loc="upper right", ncol=2)
ax1.grid(axis="y", alpha=0.3)
ax1.text(0.01, 0.97, f"Annual total: {bottom.sum():.1f} TWh",
         transform=ax1.transAxes, va="top", fontsize=9, color="#1565C0")

# --- BOTTOM: TYNDP monthly ---
bottom2 = np.zeros(12)
for cat in cats_de_tyndp:
    h = tyndp_de_monthly[cat]
    ax2.bar(x, h, bottom=bottom2, color=CAT_COLORS.get(cat, "#9E9E9E"),
            label=cat, edgecolor="white", linewidth=0.3)
    bottom2 += h
ax2.set_xticks(x)
ax2.set_xticklabels(MONTH_NAMES)
ax2.set_ylabel("Generation [TWh/month]")
ax2.set_title(f"{BUS} — TYNDP 2030 NT Plexos CY2009 Monthly Generation", fontweight="bold")
ax2.legend(fontsize=8, loc="upper right", ncol=2)
ax2.grid(axis="y", alpha=0.3)
ax2.text(0.01, 0.97, f"Annual total: {bottom2.sum():.1f} TWh",
         transform=ax2.transAxes, va="top", fontsize=9, color="#F57F17")

plt.tight_layout()
plt.show()

# Monthly comparison table
print(f"\n{BUS} — Monthly generation totals:")
print(f"  {'Month':<5} {'TYNDP TWh':>10} {'Model TWh':>10} {'Diff':>8} {'Diff%':>7}")
print("  " + "-" * 44)
m_annual, t_annual = 0.0, 0.0
for mo in range(12):
    m_tot = sum(v[mo] for v in model_de_monthly.values())
    t_tot = sum(v[mo] for v in tyndp_de_monthly.values())
    d = m_tot - t_tot
    pct = 100 * d / t_tot if t_tot > 0 else np.nan
    print(f"  {MONTH_NAMES[mo]:<5} {t_tot:10.2f} {m_tot:10.2f} {d:+8.2f} {pct:+6.1f}%")
    m_annual += m_tot; t_annual += t_tot
print("  " + "-" * 44)
d_ann = m_annual - t_annual
print(f"  {'Total':<5} {t_annual:10.2f} {m_annual:10.2f} {d_ann:+8.2f} {100*d_ann/t_annual:+6.1f}%")
# Out:
# Found 46 generation columns for DE00 in Hourly Market Data
#   col  497: Nuclear [MW]                                       → Nuclear
#   col  498: Lignite old 1 [MW]                                 → Lignite
#   col  499: Lignite old 2 [MW]                                 → Lignite
#   col  500: Lignite new [MW]                                   → Lignite
#   col  501: Lignite CCS [MW]                                   → Lignite
#   col  502: Hard coal old 1 [MW]                               → Coal
#   col  503: Hard coal old 2 [MW]                               → Coal
#   col  504: Hard coal new [MW]                                 → Coal
#   col  505: Hard coal CCS [MW]                                 → Coal
#   col  506: Gas conventional old 1 [MW]                        → Gas
#   col  507: Gas conventional old 2 [MW]                        → Gas
#   col  508: Gas CCGT old 1 [MW]                                → Gas
# ...

# %%
# DE00 — Annual generation mix: stacked bar (TYNDP vs Model)
all_cats_de = sorted(set(model_de_monthly) | set(tyndp_de_monthly),
                     key=lambda c: CAT_ORDER.index(c) if c in CAT_ORDER else 99)

tyndp_de = {cat: sum(tyndp_de_monthly.get(cat, np.zeros(12))) for cat in all_cats_de}
model_de = {cat: sum(model_de_monthly.get(cat, np.zeros(12)))  for cat in all_cats_de}
cats_show_de = [c for c in all_cats_de if tyndp_de[c] > 0.5 or model_de[c] > 0.5]

total_t = sum(tyndp_de[c] for c in cats_show_de)
total_m = sum(model_de[c]  for c in cats_show_de)
diff_de = total_m - total_t
pct_de  = 100 * diff_de / total_t
diff_color = "#c0392b" if abs(pct_de) > 5 else "#27ae60"

fig, ax = plt.subplots(figsize=(10, 7))
x = np.arange(2); w = 0.5
bottom = np.zeros(2)
for cat in cats_show_de:
    heights = np.array([tyndp_de[cat], model_de[cat]])
    color = CAT_COLORS.get(cat, "#9E9E9E")
    ax.bar(x, heights, bottom=bottom, color=color, label=cat, width=w,
           edgecolor="white", linewidth=0.4)
    for xi, (h, b) in enumerate(zip(heights, bottom)):
        if h > 2:
            ax.text(xi, b + h / 2, f"{h:.0f}", ha="center", va="center",
                    fontsize=7, color="white", fontweight="bold")
    bottom += heights

ax.set_xticks(x)
ax.set_xticklabels(["TYNDP 2030 NT\nPlexos CY2009", "PyPSA Model\nCY2009"], fontsize=12)
ax.set_ylabel("Annual generation [TWh]", fontsize=11)
ax.set_title(
    f"DE00 Annual Generation Mix — TYNDP vs Model\n"
    f"Total diff: {diff_de:+.0f} TWh  ({pct_de:+.1f}%)",
    fontsize=12, fontweight="bold", color=diff_color
)
ax.legend(loc="upper right", fontsize=8, ncol=2, framealpha=0.85)
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# table
print(f"\n{BUS} — Annual generation mix:")
print(f"  {'Category':<22} {'TYNDP TWh':>10} {'Model TWh':>10} {'Diff':>8} {'Diff%':>7}")
print("  " + "-" * 56)
for cat in cats_show_de:
    t, m = tyndp_de[cat], model_de[cat]
    d = m - t
    pct = 100 * d / t if t > 0 else float("nan")
    flag = "  !" if abs(pct) > 20 and t > 1 else ""
    print(f"  {cat:<22} {t:10.1f} {m:10.1f} {d:+8.1f} {pct:+6.1f}%{flag}")
print("  " + "-" * 56)
print(f"  {'TOTAL':<22} {total_t:10.1f} {total_m:10.1f} {diff_de:+8.1f} {pct_de:+6.1f}%")
# Out:
# DE00 — Annual generation mix:
#   Category                TYNDP TWh  Model TWh     Diff   Diff%
#   --------------------------------------------------------
#   Gas                          54.3       57.2     +2.8   +5.2%
#   Oil                           0.8        0.0     -0.7  -96.8%
#   Other Thermal                 0.6       14.5    +13.9 +2452.3%
#   Hydro Reservoir               0.7        0.6     -0.1   -9.8%
#   Hydro RoR                    16.7       16.8     +0.1   +0.3%
#   Hydro PHS                    18.8       20.9     +2.1  +11.3%
#   Wind Onshore                239.6      219.4    -20.3   -8.5%
#   Wind Offshore               130.3      128.5     -1.9   -1.4%
#   Solar PV                    190.7      189.7     -1.0   -0.5%
#   Battery                       2.5        2.6     +0.1   +5.8%
#   Hydrogen                      5.8        0.7     -5.1  -88.2%  !
#   Other RES                    70.2       48.7    -21.5  -30.6%  !
# ...

# %% [markdown]
# ## Section 3a — DE00 Monthly Solar PV: Model vs TYNDP

# %%
SOLAR_CARRIERS_OA = {"solar-pv-utility": "Solar Utility", "solar-pv-rooftop": "Solar Rooftop",
                     "solar-thermal": "Solar Thermal", "solar-thermal-w-storage": "Solar Thermal"}
SOLAR_COLORS_OA   = {"Solar Utility": "#FDD835", "Solar Rooftop": "#FFB300", "Solar Thermal": "#FF8F00"}

# TYNDP monthly solar from hmd_raw
tyndp_solar = np.zeros(12)
for ci, cat in bus_gen_cols.items():
    if cat != "Solar PV": continue
    col = f"c{ci}"
    if col not in hmd_raw.columns: continue
    vals = pd.to_numeric(hmd_raw[col], errors="coerce").fillna(0)
    for mo in range(12):
        tyndp_solar[mo] += float(vals[vals.index.month == mo + 1].sum()) / 1e6

# Model monthly solar (sub-types)
model_solar_total = np.zeros(12)
model_solar_sub   = {}
for gen_id, g in n.generators.iterrows():
    if g["bus"] != BUS or g["carrier"] not in SOLAR_CARRIERS_OA: continue
    if gen_id not in n.generators_t.p.columns: continue
    sub = SOLAR_CARRIERS_OA[g["carrier"]]
    ts  = n.generators_t.p[gen_id]
    model_solar_sub.setdefault(sub, np.zeros(12))
    for mo in range(12):
        val = float(ts[ts.index.month == mo + 1].sum()) / 1e6
        model_solar_sub[sub][mo] += val
        model_solar_total[mo]    += val

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
x = np.arange(12); w = 0.35

# Left: grouped bar
ax = axes[0]
ax.bar(x - w/2, tyndp_solar,     width=w, color="#F57F17", alpha=0.85, label=f"TYNDP Plexos ({tyndp_solar.sum():.0f} TWh/yr)")
ax.bar(x + w/2, model_solar_total, width=w, color="#1565C0", alpha=0.85, label=f"PyPSA Model ({model_solar_total.sum():.0f} TWh/yr)")
for xi, (t, m) in enumerate(zip(tyndp_solar, model_solar_total)):
    d = m - t
    ax.text(xi, max(t, m) + 0.3, f"{d:+.1f}", ha="center", fontsize=7.5,
            color="#27ae60" if d > 0 else "#c0392b")
ax.set_xticks(x); ax.set_xticklabels(MONTH_NAMES)
ax.set_ylabel("Solar generation [TWh/month]")
diff = model_solar_total.sum() - tyndp_solar.sum()
ax.set_title(f"DE00 Solar PV — TYNDP vs Model\n"
             f"TYNDP: {tyndp_solar.sum():.0f}  Model: {model_solar_total.sum():.0f}  "
             f"Diff: {diff:+.0f} TWh ({100*diff/tyndp_solar.sum():+.1f}%)",
             fontsize=10, fontweight="bold")
ax.legend(fontsize=9); ax.grid(axis="y", alpha=0.3)

# Right: model sub-type stacked + TYNDP line
ax2 = axes[1]
bottom = np.zeros(12)
for sub, vals in model_solar_sub.items():
    ax2.bar(x, vals, bottom=bottom, color=SOLAR_COLORS_OA.get(sub, "#9E9E9E"),
            label=f"Model {sub} ({vals.sum():.0f} TWh)", edgecolor="white", linewidth=0.3)
    bottom += vals
ax2.plot(x, tyndp_solar, "o--", color="#F57F17", linewidth=2, markersize=6,
         label=f"TYNDP Plexos ({tyndp_solar.sum():.0f} TWh/yr)", zorder=5)
ax2.set_xticks(x); ax2.set_xticklabels(MONTH_NAMES)
ax2.set_ylabel("Solar generation [TWh/month]")
ax2.set_title(f"DE00 Solar — Model Sub-types vs TYNDP\n"
              f"Diff: {diff:+.0f} TWh ({100*diff/tyndp_solar.sum():+.1f}%)",
              fontsize=10, fontweight="bold")
ax2.legend(fontsize=8, loc="upper left"); ax2.grid(axis="y", alpha=0.3)
plt.tight_layout(); plt.show()

print(f"\n{'Month':<5} {'TYNDP':>8} {'Model':>8} {'Diff':>8} {'Diff%':>7}")
print("-" * 40)
for i, mon in enumerate(MONTH_NAMES):
    t, m = tyndp_solar[i], model_solar_total[i]
    d = m - t; p = 100 * d / t if t > 0 else float("nan")
    print(f"{mon:<5} {t:8.2f} {m:8.2f} {d:+8.2f} {p:+6.1f}%")
print(f"{'Total':<5} {tyndp_solar.sum():8.2f} {model_solar_total.sum():8.2f} {diff:+8.2f} {100*diff/tyndp_solar.sum():+6.1f}%")
# Out:
# Month    TYNDP    Model     Diff   Diff%
# ----------------------------------------
# Jan       5.75     5.75    -0.00   -0.0%
# Feb       7.21     7.21    +0.00   +0.0%
# Mar      13.85    13.85    -0.00   -0.0%
# Apr      25.20    24.90    -0.30   -1.2%
# May      26.42    26.16    -0.26   -1.0%
# Jun      25.77    25.57    -0.20   -0.8%
# Jul      26.91    26.79    -0.12   -0.4%
# Aug      24.98    24.86    -0.13   -0.5%
# Sep      16.23    16.21    -0.02   -0.1%
# Oct       9.60     9.60    +0.00   +0.0%
# Nov       5.16     5.16    -0.00   -0.0%
# Dec       3.58     3.64    +0.06   +1.7%
# Total   190.65   189.69    -0.97   -0.5%

# %% [markdown]
# ## Section 3b — DE00 Monthly Wind (Onshore + Offshore): Model vs TYNDP

# %%
WIND_CARRIERS_OA = {"onwind": "Wind Onshore", "offwind": "Wind Offshore"}
WIND_COLORS_OA   = {"Wind Onshore": "#388E3C", "Wind Offshore": "#1B5E20"}

# TYNDP monthly wind from hmd_raw
tyndp_wind = np.zeros(12)
for ci, cat in bus_gen_cols.items():
    if cat not in ("Wind Onshore", "Wind Offshore"): continue
    col = f"c{ci}"
    if col not in hmd_raw.columns: continue
    vals = pd.to_numeric(hmd_raw[col], errors="coerce").fillna(0)
    for mo in range(12):
        tyndp_wind[mo] += float(vals[vals.index.month == mo + 1].sum()) / 1e6

# Model monthly wind (sub-types)
model_wind_total = np.zeros(12)
model_wind_sub   = {}
for gen_id, g in n.generators.iterrows():
    if g["bus"] != BUS or g["carrier"] not in WIND_CARRIERS_OA: continue
    if gen_id not in n.generators_t.p.columns: continue
    sub = WIND_CARRIERS_OA[g["carrier"]]
    ts  = n.generators_t.p[gen_id]
    model_wind_sub.setdefault(sub, np.zeros(12))
    for mo in range(12):
        val = float(ts[ts.index.month == mo + 1].sum()) / 1e6
        model_wind_sub[sub][mo] += val
        model_wind_total[mo]    += val

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
x = np.arange(12); w = 0.35

# Left: grouped bar
ax = axes[0]
ax.bar(x - w/2, tyndp_wind,      width=w, color="#F57F17", alpha=0.85, label=f"TYNDP Plexos ({tyndp_wind.sum():.0f} TWh/yr)")
ax.bar(x + w/2, model_wind_total, width=w, color="#1565C0", alpha=0.85, label=f"PyPSA Model ({model_wind_total.sum():.0f} TWh/yr)")
for xi, (t, m) in enumerate(zip(tyndp_wind, model_wind_total)):
    d = m - t
    ax.text(xi, max(t, m) + 0.3, f"{d:+.1f}", ha="center", fontsize=7.5,
            color="#27ae60" if d > 0 else "#c0392b")
ax.set_xticks(x); ax.set_xticklabels(MONTH_NAMES)
ax.set_ylabel("Wind generation [TWh/month]")
diff = model_wind_total.sum() - tyndp_wind.sum()
ax.set_title(f"DE00 Wind (Onshore + Offshore) — TYNDP vs Model\n"
             f"TYNDP: {tyndp_wind.sum():.0f}  Model: {model_wind_total.sum():.0f}  "
             f"Diff: {diff:+.0f} TWh ({100*diff/tyndp_wind.sum():+.1f}%)",
             fontsize=10, fontweight="bold")
ax.legend(fontsize=9); ax.grid(axis="y", alpha=0.3)

# Right: model sub-type stacked + TYNDP line
ax2 = axes[1]
bottom = np.zeros(12)
for sub in ["Wind Onshore", "Wind Offshore"]:
    if sub not in model_wind_sub: continue
    vals = model_wind_sub[sub]
    ax2.bar(x, vals, bottom=bottom, color=WIND_COLORS_OA[sub],
            label=f"Model {sub} ({vals.sum():.0f} TWh)", edgecolor="white", linewidth=0.3)
    bottom += vals
ax2.plot(x, tyndp_wind, "o--", color="#F57F17", linewidth=2, markersize=6,
         label=f"TYNDP Plexos ({tyndp_wind.sum():.0f} TWh/yr)", zorder=5)
ax2.set_xticks(x); ax2.set_xticklabels(MONTH_NAMES)
ax2.set_ylabel("Wind generation [TWh/month]")
ax2.set_title(f"DE00 Wind — Onshore vs Offshore split vs TYNDP\n"
              f"Diff: {diff:+.0f} TWh ({100*diff/tyndp_wind.sum():+.1f}%)",
              fontsize=10, fontweight="bold")
ax2.legend(fontsize=8, loc="upper right"); ax2.grid(axis="y", alpha=0.3)
plt.tight_layout(); plt.show()

print(f"\n{'Month':<5} {'TYNDP':>8} {'Model':>8} {'Diff':>8} {'Diff%':>7}")
print("-" * 40)
for i, mon in enumerate(MONTH_NAMES):
    t, m = tyndp_wind[i], model_wind_total[i]
    d = m - t; p = 100 * d / t if t > 0 else float("nan")
    print(f"{mon:<5} {t:8.2f} {m:8.2f} {d:+8.2f} {p:+6.1f}%")
print(f"{'Total':<5} {tyndp_wind.sum():8.2f} {model_wind_total.sum():8.2f} {diff:+8.2f} {100*diff/tyndp_wind.sum():+6.1f}%")
# Out:
# Month    TYNDP    Model     Diff   Diff%
# ----------------------------------------
# Jan      33.68    33.78    +0.10   +0.3%
# Feb      30.78    30.84    +0.06   +0.2%
# Mar      36.09    34.55    -1.54   -4.3%
# Apr      22.25    19.75    -2.50  -11.2%
# May      29.12    24.66    -4.46  -15.3%
# Jun      27.02    22.60    -4.42  -16.4%
# Jul      24.84    21.32    -3.52  -14.2%
# Aug      21.99    19.48    -2.50  -11.4%
# Sep      28.89    26.87    -2.02   -7.0%
# Oct      34.98    33.63    -1.35   -3.9%
# Nov      46.26    45.04    -1.22   -2.6%
# Dec      34.09    35.33    +1.24   +3.6%
# Total   369.98   347.84   -22.14   -6.0%

# %% [markdown]
# ## Section 3c — DE00 Monthly Demand: Model vs TYNDP

# %%
# TYNDP monthly demand — find actual demand column for BUS in HMD
# Exclude: DSR ("side response"), battery charge ("charge","storage","battery"), marginal price
demand_col_idx = None
for ci in range(2, meta_hmd.shape[1]):
    if row_zone_h.get(ci, "") != BUS: continue
    cat_str   = str(row_cat_h.get(ci, "")).strip()
    cat_lower = cat_str.lower()
    if classify_tyndp_strict(cat_str) is not None: continue   # skip known gen/storage categories
    if "demand" not in cat_lower: continue                     # must contain "demand"
    if any(kw in cat_lower for kw in ("response", "charge", "storage", "battery", "price", "curtail")):
        continue
    demand_col_idx = ci
    print(f"Found demand column {ci}: '{cat_str}'")
    break

if demand_col_idx is None:
    print("Demand column not found — using annual TYNDP demand / 12 as flat reference")
    tyndp_demand_monthly = np.full(12, float(tyndp_demand[BUS]) / 12 / 1000)
else:
    hmd_demand_raw = pd.read_excel(XLSX, sheet_name="Hourly Market Data",
                                   header=None, skiprows=13,
                                   usecols=[1, demand_col_idx], engine="openpyxl")
    hmd_demand_raw.columns = ["ts_str", "demand_mw"]
    hmd_demand_raw = hmd_demand_raw.dropna(subset=["ts_str"])
    hmd_demand_raw["timestamp"] = hmd_demand_raw["ts_str"].apply(parse_hmd_ts)
    hmd_demand_raw = hmd_demand_raw.dropna(subset=["timestamp"]).set_index("timestamp")
    hmd_demand_raw["demand_mw"] = pd.to_numeric(hmd_demand_raw["demand_mw"], errors="coerce").fillna(0)
    tyndp_demand_monthly = np.array([
        float(hmd_demand_raw["demand_mw"][hmd_demand_raw.index.month == mo + 1].sum()) / 1e6
        for mo in range(12)
    ])

# Model monthly demand
de_load_ts = n.loads_t.p_set[f"{BUS}-load"]
model_demand_monthly = np.array([
    float(de_load_ts[de_load_ts.index.month == mo + 1].sum()) / 1e6
    for mo in range(12)
])

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
x = np.arange(12); w = 0.35
diff_d = model_demand_monthly.sum() - tyndp_demand_monthly.sum()

ax = axes[0]
ax.bar(x - w/2, tyndp_demand_monthly, width=w, color="#F57F17", alpha=0.85,
       label=f"TYNDP Plexos ({tyndp_demand_monthly.sum():.0f} TWh/yr)")
ax.bar(x + w/2, model_demand_monthly, width=w, color="#1565C0", alpha=0.85,
       label=f"PyPSA Model ({model_demand_monthly.sum():.0f} TWh/yr)")
for xi, (t, m) in enumerate(zip(tyndp_demand_monthly, model_demand_monthly)):
    d = m - t
    ax.text(xi, max(t, m) + 0.3, f"{d:+.1f}", ha="center", fontsize=7.5,
            color="#27ae60" if d > 0 else "#c0392b")
ax.set_xticks(x); ax.set_xticklabels(MONTH_NAMES)
ax.set_ylabel("Demand [TWh/month]")
ax.set_title(f"DE00 Monthly Demand — TYNDP vs Model\n"
             f"TYNDP: {tyndp_demand_monthly.sum():.0f}  Model: {model_demand_monthly.sum():.0f}  "
             f"Diff: {diff_d:+.0f} TWh ({100*diff_d/tyndp_demand_monthly.sum():+.1f}%)",
             fontsize=10, fontweight="bold")
ax.legend(fontsize=9); ax.grid(axis="y", alpha=0.3)

ax2 = axes[1]
ax2.bar(x, model_demand_monthly, color="#1565C0", alpha=0.85,
        label=f"PyPSA Model ({model_demand_monthly.sum():.0f} TWh/yr)")
ax2.plot(x, tyndp_demand_monthly, "o--", color="#F57F17", linewidth=2, markersize=6,
         label=f"TYNDP Plexos ({tyndp_demand_monthly.sum():.0f} TWh/yr)", zorder=5)
ax2.set_xticks(x); ax2.set_xticklabels(MONTH_NAMES)
ax2.set_ylabel("Demand [TWh/month]")
ax2.set_title(f"DE00 Demand — Model vs TYNDP\nDiff: {diff_d:+.0f} TWh ({100*diff_d/tyndp_demand_monthly.sum():+.1f}%)",
              fontsize=10, fontweight="bold")
ax2.legend(fontsize=9); ax2.grid(axis="y", alpha=0.3)
plt.tight_layout(); plt.show()

print(f"\n{'Month':<5} {'TYNDP':>8} {'Model':>8} {'Diff':>8} {'Diff%':>7}")
print("-" * 40)
for i, mon in enumerate(MONTH_NAMES):
    t, m = tyndp_demand_monthly[i], model_demand_monthly[i]
    d = m - t; p = 100 * d / t if t > 0 else float("nan")
    print(f"{mon:<5} {t:8.2f} {m:8.2f} {d:+8.2f} {p:+6.1f}%")
print(f"{'Total':<5} {tyndp_demand_monthly.sum():8.2f} {model_demand_monthly.sum():8.2f} {diff_d:+8.2f} {100*diff_d/tyndp_demand_monthly.sum():+6.1f}%")
# Out:
# Found demand column 547: 'Demand [MW]
# (losses included)'
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x106027230>>
# Traceback (most recent call last):
#   File "/Users/radovanhodor/Library/Python/3.12/lib/python/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %% [markdown]
# ## Section 3d — DE00 Monthly Gas Generation: Model vs TYNDP

# %%
GAS_CARRIERS_OA = {"gas": "Gas", "gas-ccs": "Gas"}

# TYNDP monthly gas from hmd_raw (bus_gen_cols has Gas cols for DE00)
tyndp_gas_de = np.zeros(12)
for ci, cat in bus_gen_cols.items():
    if cat != "Gas": continue
    col = f"c{ci}"
    if col not in hmd_raw.columns: continue
    vals = pd.to_numeric(hmd_raw[col], errors="coerce").fillna(0)
    for mo in range(12):
        tyndp_gas_de[mo] += float(vals[vals.index.month == mo + 1].sum()) / 1e6

# Model monthly gas DE00 (aggregated)
model_gas_de_total = np.zeros(12)
for gen_id, g in n.generators.iterrows():
    if g["bus"] != BUS or g["carrier"] not in GAS_CARRIERS_OA: continue
    if gen_id not in n.generators_t.p.columns: continue
    ts = n.generators_t.p[gen_id]
    for mo in range(12):
        model_gas_de_total[mo] += float(ts[ts.index.month == mo + 1].sum()) / 1e6

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
x = np.arange(12); w = 0.35
diff_g = model_gas_de_total.sum() - tyndp_gas_de.sum()

ax = axes[0]
ax.bar(x - w/2, tyndp_gas_de,       width=w, color="#F57F17", alpha=0.85, label=f"TYNDP Plexos ({tyndp_gas_de.sum():.0f} TWh/yr)")
ax.bar(x + w/2, model_gas_de_total, width=w, color="#1565C0", alpha=0.85, label=f"PyPSA Model ({model_gas_de_total.sum():.0f} TWh/yr)")
for xi, (t, m) in enumerate(zip(tyndp_gas_de, model_gas_de_total)):
    d = m - t
    ax.text(xi, max(t, m) + 0.3, f"{d:+.1f}", ha="center", fontsize=7.5,
            color="#27ae60" if d > 0 else "#c0392b")
ax.set_xticks(x); ax.set_xticklabels(MONTH_NAMES)
ax.set_ylabel("Gas generation [TWh/month]")
ax.set_title(f"DE00 Gas Generation — TYNDP vs Model\n"
             f"TYNDP: {tyndp_gas_de.sum():.0f}  Model: {model_gas_de_total.sum():.0f}  "
             f"Diff: {diff_g:+.0f} TWh ({100*diff_g/tyndp_gas_de.sum():+.1f}%)",
             fontsize=10, fontweight="bold")
ax.legend(fontsize=9); ax.grid(axis="y", alpha=0.3)

ax2 = axes[1]
ax2.bar(x, model_gas_de_total, width=0.6, color="#F57F17", alpha=0.85,
        label=f"Model Gas ({model_gas_de_total.sum():.0f} TWh)")
ax2.plot(x, tyndp_gas_de, "o--", color="#1565C0", linewidth=2, markersize=6,
         label=f"TYNDP Plexos ({tyndp_gas_de.sum():.0f} TWh/yr)", zorder=5)
ax2.set_xticks(x); ax2.set_xticklabels(MONTH_NAMES)
ax2.set_ylabel("Gas generation [TWh/month]")
ax2.set_title(f"DE00 Gas — Model vs TYNDP\nDiff: {diff_g:+.0f} TWh ({100*diff_g/tyndp_gas_de.sum():+.1f}%)",
              fontsize=10, fontweight="bold")
ax2.legend(fontsize=8, loc="upper right"); ax2.grid(axis="y", alpha=0.3)
plt.tight_layout(); plt.show()

print(f"\n{'Month':<5} {'TYNDP':>8} {'Model':>8} {'Diff':>8} {'Diff%':>7}")
print("-" * 40)
for i, mon in enumerate(MONTH_NAMES):
    t, m = tyndp_gas_de[i], model_gas_de_total[i]
    d = m - t; p = 100 * d / t if t > 0 else float("nan")
    print(f"{mon:<5} {t:8.2f} {m:8.2f} {d:+8.2f} {p:+6.1f}%")
t_t, m_t = tyndp_gas_de.sum(), model_gas_de_total.sum()
print(f"{'Total':<5} {t_t:8.2f} {m_t:8.2f} {m_t-t_t:+8.2f} {100*(m_t-t_t)/t_t:+6.1f}%")
# Out:
# Month    TYNDP    Model     Diff   Diff%
# ----------------------------------------
# Jan      11.56    12.34    +0.78   +6.7%
# Feb       9.11     9.77    +0.65   +7.2%
# Mar       4.70     5.83    +1.13  +24.1%
# Apr       1.71     1.91    +0.19  +11.2%
# May       1.19     0.59    -0.60  -50.7%
# Jun       1.69     0.98    -0.71  -42.0%
# Jul       1.68     0.98    -0.70  -41.8%
# Aug       1.88     1.41    -0.46  -24.7%
# Sep       3.06     2.68    -0.37  -12.3%
# Oct       5.26     5.73    +0.47   +8.9%
# Nov       4.31     4.96    +0.66  +15.2%
# Dec       8.19     9.98    +1.79  +21.8%
# Total    54.33    57.15    +2.82   +5.2%

# %% [markdown]
# ## Sections 3d–3f — Europe-wide Monthly Solar / Wind / Demand: Model vs TYNDP
#
# Same comparisons as 3a–3c but aggregated across **all buses** in the network.

# %%
# ── Prep: read HMD for all network buses — solar + wind + gas + demand ────────
network_buses = set(n.buses.index)
EXCLUDE_KW = ("response", "charge", "storage", "battery", "price", "curtail")

all_gen_cols = {}   # col_idx → (bus, category)
all_dem_cols = {}   # col_idx → bus

for ci in range(2, meta_hmd.shape[1]):
    bus = row_zone_h.get(ci, "").strip()
    if bus not in network_buses: continue
    cat_str   = str(row_cat_h.get(ci, "")).strip()
    cat_lower = cat_str.lower()
    cat = classify_tyndp_strict(cat_str)
    if cat in ("Solar PV", "Wind Onshore", "Wind Offshore", "Gas"):
        all_gen_cols[ci] = (bus, cat)
    elif (cat is None and "demand" in cat_lower
          and not any(kw in cat_lower for kw in EXCLUDE_KW)):
        all_dem_cols[ci] = bus

print(f"Solar+Wind+Gas gen cols: {len(all_gen_cols)}  |  Demand cols: {len(all_dem_cols)}")

usecols_eu = [1] + sorted(set(all_gen_cols) | set(all_dem_cols))
hmd_eu = pd.read_excel(XLSX, sheet_name="Hourly Market Data",
                       header=None, skiprows=13, usecols=usecols_eu, engine="openpyxl")
hmd_eu.columns = ["ts_str"] + [f"c{ci}" for ci in sorted(set(all_gen_cols) | set(all_dem_cols))]
hmd_eu = hmd_eu.dropna(subset=["ts_str"])
hmd_eu["timestamp"] = hmd_eu["ts_str"].apply(parse_hmd_ts)
hmd_eu = hmd_eu.dropna(subset=["timestamp"]).set_index("timestamp")

tyndp_eu_solar  = np.zeros(12)
tyndp_eu_wind   = np.zeros(12)
tyndp_eu_gas    = np.zeros(12)
tyndp_eu_demand = np.zeros(12)

for ci, (bus, cat) in all_gen_cols.items():
    col = f"c{ci}"
    if col not in hmd_eu.columns: continue
    vals = pd.to_numeric(hmd_eu[col], errors="coerce").fillna(0)
    monthly = np.array([float(vals[vals.index.month == mo + 1].sum()) / 1e6 for mo in range(12)])
    if   cat == "Solar PV": tyndp_eu_solar += monthly
    elif cat == "Gas":      tyndp_eu_gas   += monthly
    else:                   tyndp_eu_wind  += monthly

for ci, bus in all_dem_cols.items():
    col = f"c{ci}"
    if col not in hmd_eu.columns: continue
    vals = pd.to_numeric(hmd_eu[col], errors="coerce").fillna(0)
    tyndp_eu_demand += np.array([float(vals[vals.index.month == mo + 1].sum()) / 1e6 for mo in range(12)])

print(f"TYNDP EU  Solar: {tyndp_eu_solar.sum():.0f}  Wind: {tyndp_eu_wind.sum():.0f}  Gas: {tyndp_eu_gas.sum():.0f}  Demand: {tyndp_eu_demand.sum():.0f} TWh")

# ── Model EU aggregates ───────────────────────────────────────────────────────
SOLAR_SET = {"solar-pv-utility", "solar-pv-rooftop", "solar-thermal", "solar-thermal-w-storage"}
WIND_SET  = {"onwind", "offwind"}
GAS_SET   = {"gas", "gas-ccs"}
SOLAR_SUB = {"solar-pv-utility": "Solar Utility", "solar-pv-rooftop": "Solar Rooftop",
             "solar-thermal": "Solar Thermal", "solar-thermal-w-storage": "Solar Thermal"}
WIND_SUB  = {"onwind": "Wind Onshore", "offwind": "Wind Offshore"}
GAS_SUB   = {"gas": "Gas CCGT", "gas-ccs": "Gas CCS"}

model_eu_solar_total = np.zeros(12); model_eu_solar_sub = {}
model_eu_wind_total  = np.zeros(12); model_eu_wind_sub  = {}
model_eu_gas_total   = np.zeros(12); model_eu_gas_sub   = {}

for gen_id, g in n.generators.iterrows():
    if gen_id not in n.generators_t.p.columns: continue
    carrier = g["carrier"]
    ts = n.generators_t.p[gen_id]
    monthly = np.array([float(ts[ts.index.month == mo + 1].sum()) / 1e6 for mo in range(12)])
    if carrier in SOLAR_SET:
        sub = SOLAR_SUB[carrier]; model_eu_solar_sub.setdefault(sub, np.zeros(12))
        model_eu_solar_sub[sub] += monthly; model_eu_solar_total += monthly
    elif carrier in WIND_SET:
        sub = WIND_SUB[carrier]; model_eu_wind_sub.setdefault(sub, np.zeros(12))
        model_eu_wind_sub[sub] += monthly; model_eu_wind_total += monthly
    elif carrier in GAS_SET:
        sub = GAS_SUB[carrier]; model_eu_gas_sub.setdefault(sub, np.zeros(12))
        model_eu_gas_sub[sub] += monthly; model_eu_gas_total += monthly

model_eu_demand = np.zeros(12)
for col in n.loads_t.p_set.columns:
    ts = n.loads_t.p_set[col]
    model_eu_demand += np.array([float(ts[ts.index.month == mo + 1].sum()) / 1e6 for mo in range(12)])

# Model demand by bus (for stacked right panel)
bus_demand_monthly = {}
for load_id in n.loads_t.p_set.columns:
    bus = n.loads.at[load_id, "bus"]
    ts  = n.loads_t.p_set[load_id]
    monthly = np.array([float(ts[ts.index.month == mo + 1].sum()) / 1e6 for mo in range(12)])
    bus_demand_monthly[bus] = bus_demand_monthly.get(bus, np.zeros(12)) + monthly

print(f"Model  EU  Solar: {model_eu_solar_total.sum():.0f}  Wind: {model_eu_wind_total.sum():.0f}  Gas: {model_eu_gas_total.sum():.0f}  Demand: {model_eu_demand.sum():.0f} TWh")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       5 all_gen_cols = {}   # col_idx → (bus, category)
#       6 all_dem_cols = {}   # col_idx → bus
# ----> 8 for ci in range(2, meta_hmd.shape[1]):
#       9     bus = row_zone_h.get(ci, "").strip()
#      10     if bus not in network_buses: continue
#
# NameError: name 'meta_hmd' is not defined

# %%
# Section 3d — Europe-wide Solar PV
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
x = np.arange(12); w = 0.35
diff_s = model_eu_solar_total.sum() - tyndp_eu_solar.sum()

ax = axes[0]
ax.bar(x - w/2, tyndp_eu_solar,       width=w, color="#F57F17", alpha=0.85, label=f"TYNDP Plexos ({tyndp_eu_solar.sum():.0f} TWh/yr)")
ax.bar(x + w/2, model_eu_solar_total, width=w, color="#1565C0", alpha=0.85, label=f"PyPSA Model ({model_eu_solar_total.sum():.0f} TWh/yr)")
for xi, (t, m) in enumerate(zip(tyndp_eu_solar, model_eu_solar_total)):
    d = m - t
    ax.text(xi, max(t, m) + 1, f"{d:+.0f}", ha="center", fontsize=7.5,
            color="#27ae60" if d > 0 else "#c0392b")
ax.set_xticks(x); ax.set_xticklabels(MONTH_NAMES)
ax.set_ylabel("Solar generation [TWh/month]")
ax.set_title(f"Europe-wide Solar PV — TYNDP vs Model\n"
             f"TYNDP: {tyndp_eu_solar.sum():.0f}  Model: {model_eu_solar_total.sum():.0f}  "
             f"Diff: {diff_s:+.0f} TWh ({100*diff_s/tyndp_eu_solar.sum():+.1f}%)",
             fontsize=10, fontweight="bold")
ax.legend(fontsize=9); ax.grid(axis="y", alpha=0.3)

ax2 = axes[1]
bottom = np.zeros(12)
for sub, vals in model_eu_solar_sub.items():
    ax2.bar(x, vals, bottom=bottom, color=SOLAR_COLORS_OA.get(sub, "#9E9E9E"),
            label=f"Model {sub} ({vals.sum():.0f} TWh)", edgecolor="white", linewidth=0.3)
    bottom += vals
ax2.plot(x, tyndp_eu_solar, "o--", color="#F57F17", linewidth=2, markersize=6,
         label=f"TYNDP Plexos ({tyndp_eu_solar.sum():.0f} TWh/yr)", zorder=5)
ax2.set_xticks(x); ax2.set_xticklabels(MONTH_NAMES)
ax2.set_ylabel("Solar generation [TWh/month]")
ax2.set_title(f"Europe-wide Solar — Sub-types vs TYNDP\nDiff: {diff_s:+.0f} TWh ({100*diff_s/tyndp_eu_solar.sum():+.1f}%)",
              fontsize=10, fontweight="bold")
ax2.legend(fontsize=8, loc="upper left"); ax2.grid(axis="y", alpha=0.3)
plt.tight_layout(); plt.show()

print(f"\n{'Month':<5} {'TYNDP':>8} {'Model':>8} {'Diff':>8} {'Diff%':>7}")
print("-" * 40)
for i, mon in enumerate(MONTH_NAMES):
    t, m = tyndp_eu_solar[i], model_eu_solar_total[i]
    d = m - t; p = 100 * d / t if t > 0 else float("nan")
    print(f"{mon:<5} {t:8.1f} {m:8.1f} {d:+8.1f} {p:+6.1f}%")
print(f"{'Total':<5} {tyndp_eu_solar.sum():8.1f} {model_eu_solar_total.sum():8.1f} {diff_s:+8.1f} {100*diff_s/tyndp_eu_solar.sum():+6.1f}%")
# Out:
# Month    TYNDP    Model     Diff   Diff%
# ----------------------------------------
# Jan       30.7     34.2     +3.5  +11.3%
# Feb       40.6     43.0     +2.4   +5.9%
# Mar       66.4     68.1     +1.7   +2.6%
# Apr       91.2     91.8     +0.7   +0.7%
# May      100.5    100.8     +0.3   +0.3%
# Jun       96.9     98.1     +1.2   +1.2%
# Jul      101.2    102.6     +1.5   +1.5%
# Aug       92.8     94.6     +1.9   +2.0%
# Sep       68.3     70.9     +2.7   +3.9%
# Oct       49.8     52.6     +2.8   +5.7%
# Nov       30.7     34.1     +3.4  +11.1%
# Dec       22.9     26.9     +4.1  +17.8%
# Total    791.8    817.9    +26.1   +3.3%

# %%
# Section 3e — Europe-wide Wind (Onshore + Offshore)
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
x = np.arange(12); w = 0.35
diff_w = model_eu_wind_total.sum() - tyndp_eu_wind.sum()

ax = axes[0]
ax.bar(x - w/2, tyndp_eu_wind,      width=w, color="#F57F17", alpha=0.85, label=f"TYNDP Plexos ({tyndp_eu_wind.sum():.0f} TWh/yr)")
ax.bar(x + w/2, model_eu_wind_total, width=w, color="#1565C0", alpha=0.85, label=f"PyPSA Model ({model_eu_wind_total.sum():.0f} TWh/yr)")
for xi, (t, m) in enumerate(zip(tyndp_eu_wind, model_eu_wind_total)):
    d = m - t
    ax.text(xi, max(t, m) + 1, f"{d:+.0f}", ha="center", fontsize=7.5,
            color="#27ae60" if d > 0 else "#c0392b")
ax.set_xticks(x); ax.set_xticklabels(MONTH_NAMES)
ax.set_ylabel("Wind generation [TWh/month]")
ax.set_title(f"Europe-wide Wind (Onshore + Offshore) — TYNDP vs Model\n"
             f"TYNDP: {tyndp_eu_wind.sum():.0f}  Model: {model_eu_wind_total.sum():.0f}  "
             f"Diff: {diff_w:+.0f} TWh ({100*diff_w/tyndp_eu_wind.sum():+.1f}%)",
             fontsize=10, fontweight="bold")
ax.legend(fontsize=9); ax.grid(axis="y", alpha=0.3)

ax2 = axes[1]
bottom = np.zeros(12)
for sub in ["Wind Onshore", "Wind Offshore"]:
    if sub not in model_eu_wind_sub: continue
    vals = model_eu_wind_sub[sub]
    ax2.bar(x, vals, bottom=bottom, color=WIND_COLORS_OA[sub],
            label=f"Model {sub} ({vals.sum():.0f} TWh)", edgecolor="white", linewidth=0.3)
    bottom += vals
ax2.plot(x, tyndp_eu_wind, "o--", color="#F57F17", linewidth=2, markersize=6,
         label=f"TYNDP Plexos ({tyndp_eu_wind.sum():.0f} TWh/yr)", zorder=5)
ax2.set_xticks(x); ax2.set_xticklabels(MONTH_NAMES)
ax2.set_ylabel("Wind generation [TWh/month]")
ax2.set_title(f"Europe-wide Wind — Onshore vs Offshore split vs TYNDP\nDiff: {diff_w:+.0f} TWh ({100*diff_w/tyndp_eu_wind.sum():+.1f}%)",
              fontsize=10, fontweight="bold")
ax2.legend(fontsize=8, loc="upper right"); ax2.grid(axis="y", alpha=0.3)
plt.tight_layout(); plt.show()

print(f"\n{'Month':<5} {'TYNDP':>8} {'Model':>8} {'Diff':>8} {'Diff%':>7}")
print("-" * 40)
for i, mon in enumerate(MONTH_NAMES):
    t, m = tyndp_eu_wind[i], model_eu_wind_total[i]
    d = m - t; p = 100 * d / t if t > 0 else float("nan")
    print(f"{mon:<5} {t:8.1f} {m:8.1f} {d:+8.1f} {p:+6.1f}%")
print(f"{'Total':<5} {tyndp_eu_wind.sum():8.1f} {model_eu_wind_total.sum():8.1f} {diff_w:+8.1f} {100*diff_w/tyndp_eu_wind.sum():+6.1f}%")
# Out:
# Month    TYNDP    Model     Diff   Diff%
# ----------------------------------------
# Jan      157.5    153.6     -3.9   -2.5%
# Feb      129.9    128.5     -1.4   -1.1%
# Mar      153.8    142.2    -11.5   -7.5%
# Apr      104.5     93.8    -10.7  -10.2%
# May      125.7    106.5    -19.2  -15.2%
# Jun       97.6     87.1    -10.6  -10.8%
# Jul      105.2     94.5    -10.8  -10.2%
# Aug      102.1     90.6    -11.6  -11.3%
# Sep      125.2    114.5    -10.7   -8.6%
# Oct      135.8    127.7     -8.1   -6.0%
# Nov      182.0    171.4    -10.6   -5.8%
# Dec      151.2    155.3     +4.1   +2.7%
# Total   1570.6   1465.8   -104.9   -6.7%

# %%
# Section 3f — Europe-wide Demand
import matplotlib.cm as cm
bus_annual = {b: v.sum() for b, v in bus_demand_monthly.items()}
top_buses  = sorted(bus_annual, key=lambda b: bus_annual[b], reverse=True)[:10]
rest_buses = [b for b in bus_annual if b not in top_buses]
demand_stacked = {b: bus_demand_monthly[b] for b in top_buses}
if rest_buses:
    demand_stacked["Other"] = sum(bus_demand_monthly[b] for b in rest_buses)
bus_palette = cm.tab20.colors
bus_colors  = {b: bus_palette[i % 20] for i, b in enumerate(demand_stacked)}
bus_colors["Other"] = "#BDBDBD"

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
x = np.arange(12); w = 0.35
diff_d = model_eu_demand.sum() - tyndp_eu_demand.sum()

ax = axes[0]
ax.bar(x - w/2, tyndp_eu_demand, width=w, color="#F57F17", alpha=0.85, label=f"TYNDP Plexos ({tyndp_eu_demand.sum():.0f} TWh/yr)")
ax.bar(x + w/2, model_eu_demand, width=w, color="#1565C0", alpha=0.85, label=f"PyPSA Model ({model_eu_demand.sum():.0f} TWh/yr)")
for xi, (t, m) in enumerate(zip(tyndp_eu_demand, model_eu_demand)):
    d = m - t
    ax.text(xi, max(t, m) + 1, f"{d:+.0f}", ha="center", fontsize=7.5,
            color="#27ae60" if d > 0 else "#c0392b")
ax.set_xticks(x); ax.set_xticklabels(MONTH_NAMES)
ax.set_ylabel("Demand [TWh/month]")
ax.set_title(f"Europe-wide Demand — TYNDP vs Model\n"
             f"TYNDP: {tyndp_eu_demand.sum():.0f}  Model: {model_eu_demand.sum():.0f}  "
             f"Diff: {diff_d:+.0f} TWh ({100*diff_d/tyndp_eu_demand.sum():+.1f}%)",
             fontsize=10, fontweight="bold")
ax.legend(fontsize=9); ax.grid(axis="y", alpha=0.3)

ax2 = axes[1]
bottom = np.zeros(12)
for bus, vals in demand_stacked.items():
    ax2.bar(x, vals, bottom=bottom, color=bus_colors[bus],
            label=f"{bus} ({vals.sum():.0f} TWh)", edgecolor="white", linewidth=0.3)
    bottom += vals
ax2.plot(x, tyndp_eu_demand, "o--", color="#F57F17", linewidth=2, markersize=6,
         label=f"TYNDP Plexos ({tyndp_eu_demand.sum():.0f} TWh/yr)", zorder=5)
ax2.set_xticks(x); ax2.set_xticklabels(MONTH_NAMES)
ax2.set_ylabel("Demand [TWh/month]")
ax2.set_title(f"Europe-wide Demand — by Country vs TYNDP\nDiff: {diff_d:+.0f} TWh ({100*diff_d/tyndp_eu_demand.sum():+.1f}%)",
              fontsize=10, fontweight="bold")
ax2.legend(fontsize=7, loc="upper right", ncol=2); ax2.grid(axis="y", alpha=0.3)
plt.tight_layout(); plt.show()

print(f"\n{'Month':<5} {'TYNDP':>8} {'Model':>8} {'Diff':>8} {'Diff%':>7}")
print("-" * 40)
for i, mon in enumerate(MONTH_NAMES):
    t, m = tyndp_eu_demand[i], model_eu_demand[i]
    d = m - t; p = 100 * d / t if t > 0 else float("nan")
    print(f"{mon:<5} {t:8.1f} {m:8.1f} {d:+8.1f} {p:+6.1f}%")
print(f"{'Total':<5} {tyndp_eu_demand.sum():8.1f} {model_eu_demand.sum():8.1f} {diff_d:+8.1f} {100*diff_d/tyndp_eu_demand.sum():+6.1f}%")
# Out:
# Month    TYNDP    Model     Diff   Diff%
# ----------------------------------------
# Jan      399.2    402.8     +3.6   +0.9%
# Feb      352.7    355.9     +3.2   +0.9%
# Mar      356.9    358.8     +1.9   +0.5%
# Apr      299.6    300.0     +0.3   +0.1%
# May      297.5    296.8     -0.7   -0.2%
# Jun      292.8    291.9     -0.9   -0.3%
# Jul      305.9    304.9     -1.1   -0.4%
# Aug      303.0    301.9     -1.1   -0.4%
# Sep      292.5    291.8     -0.7   -0.2%
# Oct      326.6    327.1     +0.5   +0.2%
# Nov      333.7    335.5     +1.8   +0.5%
# Dec      365.7    380.2    +14.5   +4.0%
# Total   3926.2   3947.5    +21.3   +0.5%

# %% [markdown]
# ## Section 3g — Europe-wide Monthly Gas Generation: Model vs TYNDP
#
# Same two-panel layout as solar/wind/demand: left = grouped bars (TYNDP vs Model), right = model sub-types stacked (Gas CCGT + Gas CCS) with TYNDP line overlay.

# %%
# Section 3g — Europe-wide Gas Generation

MONTHS = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
x = np.arange(12)
w = 0.35

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# ── Left panel: TYNDP vs Model grouped bars ──────────────────────────────────
ax = axes[0]
ax.bar(x - w/2, tyndp_eu_gas,       width=w, label=f"TYNDP ({tyndp_eu_gas.sum():.0f} TWh/yr)", color="#1565C0", alpha=0.85)
ax.bar(x + w/2, model_eu_gas_total, width=w, label=f"Model ({model_eu_gas_total.sum():.0f} TWh/yr)", color="#F57F17", alpha=0.85)
for xi, (t, m) in enumerate(zip(tyndp_eu_gas, model_eu_gas_total)):
    d = m - t
    ax.text(xi, max(t, m) + 0.3, f"{d:+.1f}", ha="center", fontsize=7.5,
            color="#27ae60" if d > 0 else "#c0392b")
ax.set_xticks(x); ax.set_xticklabels(MONTHS)
ax.set_ylabel("TWh")
diff = model_eu_gas_total.sum() - tyndp_eu_gas.sum()
ax.set_title(f"Europe-wide Gas Generation — TYNDP vs Model\n"
             f"Diff: {diff:+.1f} TWh ({100*diff/tyndp_eu_gas.sum():+.1f}%)", fontsize=10, fontweight="bold")
ax.legend(); ax.grid(axis="y", alpha=0.3)

# ── Right panel: model aggregated bar + TYNDP line ───────────────────────────
ax2 = axes[1]
ax2.bar(x, model_eu_gas_total, width=0.6, label=f"Model Gas ({model_eu_gas_total.sum():.0f} TWh)", color="#F57F17", alpha=0.85)
ax2.plot(x, tyndp_eu_gas, "o-", color="#1565C0", linewidth=2, label=f"TYNDP ({tyndp_eu_gas.sum():.0f} TWh/yr)", zorder=5)
for xi, (t, m) in enumerate(zip(tyndp_eu_gas, model_eu_gas_total)):
    d = m - t
    ax2.text(xi, max(t, m) + 0.3, f"{d:+.1f}", ha="center", fontsize=7.5,
             color="#27ae60" if d > 0 else "#c0392b")
ax2.set_xticks(x); ax2.set_xticklabels(MONTHS)
ax2.set_ylabel("TWh"); ax2.set_title("Europe-wide Gas — Model vs TYNDP")
ax2.legend(); ax2.grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.show()

# ── Monthly table ─────────────────────────────────────────────────────────────
print(f"\n{'Month':<5} {'TYNDP':>8} {'Model':>8} {'Diff':>8} {'Diff%':>7}")
print("-" * 40)
for i, mon in enumerate(MONTHS):
    t, m = tyndp_eu_gas[i], model_eu_gas_total[i]
    d = m - t; p = 100 * d / t if t > 0 else float("nan")
    print(f"{mon:<5} {t:8.2f} {m:8.2f} {d:+8.2f} {p:+6.1f}%")
print("-" * 40)
t_t, m_t = tyndp_eu_gas.sum(), model_eu_gas_total.sum()
print(f"{'Total':<5} {t_t:8.2f} {m_t:8.2f} {m_t-t_t:+8.2f} {100*(m_t-t_t)/t_t:+6.1f}%")
# Out:
# Month    TYNDP    Model     Diff   Diff%
# ----------------------------------------
# Jan      60.97    60.23    -0.73   -1.2%
# Feb      48.09    48.63    +0.54   +1.1%
# Mar      27.93    28.34    +0.42   +1.5%
# Apr      16.45    14.17    -2.28  -13.9%
# May      15.77    10.75    -5.02  -31.9%
# Jun      18.46    14.42    -4.04  -21.9%
# Jul      21.33    15.08    -6.25  -29.3%
# Aug      24.87    19.05    -5.82  -23.4%
# Sep      23.72    19.49    -4.23  -17.8%
# Oct      32.17    33.89    +1.72   +5.4%
# Nov      30.97    31.64    +0.66   +2.1%
# Dec      46.66    51.79    +5.13  +11.0%
# ----------------------------------------
# Total   367.38   347.47   -19.91   -5.4%

# %% [markdown]
# ## Section 3h — Europe-wide Monthly Generation Detail
#
# **Top:** Monthly generation by category — PyPSA model (all buses aggregated).
# **Bottom:** Monthly generation by category — TYNDP 2030 NT Plexos CY2009 (all buses in Hourly Market Data).
# Same colour scheme as Section 3 (DE00) for direct comparison.

# %%
# Section 3h — Europe-wide Monthly Generation Detail
# Reuses: meta_hmd, row_cat_h, row_zone_h, classify_tyndp_strict, parse_hmd_ts (from Section 3)

network_buses_all = set(n.buses.index)

# ── 1. TYNDP: collect ALL generation columns for all network buses ────────────
all_gen_cols_full = {}   # col_idx → (bus, cat)
for ci in range(2, meta_hmd.shape[1]):
    bus = str(row_zone_h.get(ci, "")).strip()
    if bus not in network_buses_all: continue
    cat = classify_tyndp_strict(str(row_cat_h.get(ci, "")))
    if cat is None: continue
    all_gen_cols_full[ci] = (bus, cat)

print(f"Total TYNDP generation columns across all buses: {len(all_gen_cols_full)}")

usecols_full = [1] + sorted(all_gen_cols_full.keys())
hmd_full = pd.read_excel(XLSX, sheet_name="Hourly Market Data",
                         header=None, skiprows=13, usecols=usecols_full, engine="openpyxl")
hmd_full.columns = ["ts_str"] + [f"c{ci}" for ci in sorted(all_gen_cols_full.keys())]
hmd_full = hmd_full.dropna(subset=["ts_str"])
hmd_full["timestamp"] = hmd_full["ts_str"].apply(parse_hmd_ts)
hmd_full = hmd_full.dropna(subset=["timestamp"]).set_index("timestamp")

tyndp_eu_all = {}   # cat → np.zeros(12) TWh
for ci, (bus, cat) in all_gen_cols_full.items():
    col = f"c{ci}"
    if col not in hmd_full.columns: continue
    series = pd.to_numeric(hmd_full[col], errors="coerce").fillna(0).clip(lower=0)
    tyndp_eu_all.setdefault(cat, np.zeros(12))
    for mo in range(12):
        tyndp_eu_all[cat][mo] += float(series[series.index.month == mo + 1].sum()) / 1e6

# ── 2. Model: aggregate all buses, all categories ────────────────────────────
model_eu_all = {}
for gen_id, g in n.generators.iterrows():
    if gen_id not in n.generators_t.p.columns: continue
    cat = carrier_to_cat(g["carrier"])
    if cat is None: continue
    ts = n.generators_t.p[gen_id]
    model_eu_all.setdefault(cat, np.zeros(12))
    for mo in range(12):
        model_eu_all[cat][mo] += float(ts[ts.index.month == mo + 1].sum()) / 1e6

for su_id, s in n.storage_units.iterrows():
    if su_id not in n.storage_units_t.p.columns: continue
    cat = carrier_to_cat(s["carrier"])
    if cat is None: continue
    ts = n.storage_units_t.p[su_id].clip(lower=0)
    model_eu_all.setdefault(cat, np.zeros(12))
    for mo in range(12):
        model_eu_all[cat][mo] += float(ts[ts.index.month == mo + 1].sum()) / 1e6

cats_eu_model_all = [c for c in CAT_ORDER if c in model_eu_all and max(model_eu_all[c]) > 0.1]
cats_eu_tyndp_all = [c for c in CAT_ORDER if c in tyndp_eu_all  and max(tyndp_eu_all[c])  > 0.1]

# ── 3. Plot ───────────────────────────────────────────────────────────────────
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 12))
x = np.arange(12)

# --- TOP: Model ---
bottom = np.zeros(12)
for cat in cats_eu_model_all:
    h = model_eu_all[cat]
    ax1.bar(x, h, bottom=bottom, color=CAT_COLORS.get(cat, "#9E9E9E"),
            label=cat, edgecolor="white", linewidth=0.3)
    bottom += h
ax1.set_xticks(x); ax1.set_xticklabels(MONTH_NAMES)
ax1.set_ylabel("Generation [TWh/month]")
ax1.set_title("Europe-wide — PyPSA Model Monthly Generation", fontweight="bold")
ax1.legend(fontsize=8, loc="upper right", ncol=2)
ax1.grid(axis="y", alpha=0.3)
ax1.text(0.01, 0.97, f"Annual total: {bottom.sum():.1f} TWh",
         transform=ax1.transAxes, va="top", fontsize=9, color="#1565C0")

# --- BOTTOM: TYNDP ---
bottom2 = np.zeros(12)
for cat in cats_eu_tyndp_all:
    h = tyndp_eu_all[cat]
    ax2.bar(x, h, bottom=bottom2, color=CAT_COLORS.get(cat, "#9E9E9E"),
            label=cat, edgecolor="white", linewidth=0.3)
    bottom2 += h
ax2.set_xticks(x); ax2.set_xticklabels(MONTH_NAMES)
ax2.set_ylabel("Generation [TWh/month]")
ax2.set_title("Europe-wide — TYNDP 2030 NT Plexos CY2009 Monthly Generation", fontweight="bold")
ax2.legend(fontsize=8, loc="upper right", ncol=2)
ax2.grid(axis="y", alpha=0.3)
ax2.text(0.01, 0.97, f"Annual total: {bottom2.sum():.1f} TWh",
         transform=ax2.transAxes, va="top", fontsize=9, color="#F57F17")

plt.tight_layout()
plt.show()

# ── Monthly totals table ──────────────────────────────────────────────────────
print(f"\nEurope-wide monthly generation totals:")
# print(f"  {'Month':<5} {'Model TWh':>10} {'TYNDP TWh':>10} {'Diff':>8} {'Diff%':>7}")
print(f" {'Month':<5} {'TYNDP':>10} {'Model':>10} {'Diff':>8} {'Diff%':>7}")
print("  " + "-" * 44)
m_annual, t_annual = 0.0, 0.0
for mo in range(12):
    m_tot = sum(v[mo] for v in model_eu_all.values())
    t_tot = sum(v[mo] for v in tyndp_eu_all.values())
    d = m_tot - t_tot
    pct = 100 * d / t_tot if t_tot > 0 else float("nan")
    print(f"  {MONTH_NAMES[mo]:<5} {m_tot:10.2f} {t_tot:10.2f} {d:+8.2f} {pct:+6.1f}%")
    m_annual += m_tot; t_annual += t_tot
print("  " + "-" * 44)
d_ann = m_annual - t_annual
# print(f"  {'Total':<5} {m_annual:10.2f} {t_annual:10.2f} {d_ann:+8.2f} {100*d_ann/t_annual:+6.1f}%")
print(f"  {'Total':<5} {t_annual:10.2f} {m_annual:10.2f} {d_ann:+8.2f} {100*d_ann/t_annual:+6.1f}%")
# Out:
# Total TYNDP generation columns across all buses: 2392
# Europe-wide monthly generation totals:
#  Month      TYNDP      Model     Diff   Diff%
#   --------------------------------------------
#   Jan       412.78     433.58   -20.80   -4.8%
#   Feb       366.87     382.33   -15.45   -4.0%
#   Mar       376.35     407.52   -31.18   -7.7%
#   Apr       321.20     354.36   -33.16   -9.4%
#   May       319.12     364.76   -45.64  -12.5%
#   Jun       310.91     345.51   -34.60  -10.0%
#   Jul       324.80     361.25   -36.44  -10.1%
#   Aug       319.81     355.14   -35.34   -9.9%
#   Sep       308.86     342.91   -34.05   -9.9%
#   Oct       340.81     366.70   -25.89   -7.1%
#   Nov       348.94     380.92   -31.98   -8.4%
#   Dec       390.60     394.34    -3.73   -0.9%
#   --------------------------------------------
#   Total    4489.32    4141.04  -348.27   -7.8%

# %%
# Technology breakdown from Hourly Market Data (consistent with monthly totals)
# Uses tyndp_eu_all from Section 3h and model_eu_all

print(f"{'Category':<22} {'TYNDP':>8} {'Model':>8} {'Diff':>8} {'Diff%':>7}")
print("-" * 57)
all_cats_hmd = sorted(set(list(tyndp_eu_all.keys()) + list(model_eu_all.keys())),
                      key=lambda c: CAT_ORDER.index(c) if c in CAT_ORDER else 999)
total_t_hmd, total_m_hmd = 0.0, 0.0
for cat in all_cats_hmd:
    t = sum(tyndp_eu_all.get(cat, [0]))
    m = sum(model_eu_all.get(cat, [0]))
    if t < 0.1 and m < 0.1:
        continue
    d = m - t
    pct = 100 * d / t if t > 0.5 else float('nan')
    print(f"{cat:<22} {t:8.1f} {m:8.1f} {d:+8.1f} {pct:+6.1f}%")
    total_t_hmd += t
    total_m_hmd += m
print("-" * 57)
d_total = total_m_hmd - total_t_hmd
print(f"{'TOTAL':<22} {total_t_hmd:8.1f} {total_m_hmd:8.1f} {d_total:+8.1f} {100*d_total/total_t_hmd:+6.1f}%")
print(f"\nNote: Yearly Outputs total was 4470 TWh, Hourly Market Data total is {total_t_hmd:.1f} TWh")
# Out:
# Category                  TYNDP    Model     Diff   Diff%
# ---------------------------------------------------------
# Nuclear                   601.6    602.2     +0.6   +0.1%
# Lignite                    15.0      0.1    -14.9  -99.5%
# Coal                       28.7      3.5    -25.2  -87.8%
# Gas                       367.4    347.5    -19.9   -5.4%
# Oil                         2.9      0.8     -2.1  -71.4%
# Other Thermal             111.9     64.5    -47.4  -42.4%
# Hydro Reservoir           334.5    302.1    -32.4   -9.7%
# Hydro RoR                 199.0    201.6     +2.6   +1.3%
# Hydro PHS                 103.8    112.1     +8.3   +7.9%
# Wind Onshore              958.2    838.3   -119.9  -12.5%
# Wind Offshore             612.4    627.4    +15.0   +2.5%
# Solar PV                  791.8    817.9    +26.1   +3.3%
# Battery                    59.8     50.8     -9.0  -15.0%
# Hydrogen                    6.5      0.9     -5.6  -85.9%
# ...

# %% [markdown]
# Category                  TYNDP    Model     Diff   Diff%
# ---------------------------------------------------------
# Nuclear                   601.6    602.2     +0.6   +0.1%
# Lignite                    15.0      0.1    -14.9  -99.5%
# Coal                       28.7      3.5    -25.2  -87.8%
# Gas                       367.4    347.5    -19.9   -5.4%
# Oil                         2.9      0.8     -2.1  -71.4%
# Other Thermal             111.9     64.5    -47.4  -42.4%
# Hydro Reservoir           334.5    302.1    -32.4   -9.7%
# Hydro RoR                 199.0    201.6     +2.6   +1.3%
# Hydro PHS                 103.8    112.1     +8.3   +7.9%
# Wind Onshore              958.2    838.3   -119.9  -12.5%
# Wind Offshore             612.4    627.4    +15.0   +2.5%
# Solar PV                  791.8    817.9    +26.1   +3.3%
# Battery                    59.8     50.8     -9.0  -15.0%
# Hydrogen                    6.5      0.9     -5.6  -85.9%
# Other RES                 212.9    124.0    -88.8  -41.7%
# DSR                        82.9     47.2    -35.7  -43.0%
# ---------------------------------------------------------
# TOTAL                    4489.3   4141.0   -348.3   -7.8%
#
# Note: Yearly Outputs total was 4470 TWh, Hourly Market Data total is 4489.3 TWh

# %% [markdown]
# 601.6
# 15.0
# 28.7
# 367.4
# 2.9
# 111.9
# 334.5
# 199.0
# 103.8
# 958.2
# 612.4
# 791.8
# 59.8
# 6.5
# 212.9
# 82.9

# %% [markdown]
# ## Section 3i — Energy Balance Comparison: Model vs TYNDP
#
# Side-by-side breakdown of where electricity goes in each system.

# %%
# Section 3i — Energy balance: Model vs TYNDP

TWH = 1e6
PHS_CARRIERS = {"hydro-phs", "hydro-phs-pure"}
BAT_CARRIERS = {"battery"}
VRE_CARRIERS = {"onwind", "offwind", "solar-pv-utility", "solar-pv-rooftop",
                "solar-thermal", "solar-thermal-w-storage"}

phs_ids = n.storage_units[n.storage_units.carrier.isin(PHS_CARRIERS)].index
bat_ids = n.storage_units[n.storage_units.carrier.isin(BAT_CARRIERS)].index

def _charge(ids):
    cols = [i for i in ids if i in n.storage_units_t.p.columns]
    return float(n.storage_units_t.p[cols].clip(upper=0).abs().sum().sum()) / TWH if cols else 0.0

model_demand     = n.loads_t.p_set.values.sum() / TWH
model_phs_charge = _charge(phs_ids)
model_bat_charge = _charge(bat_ids)
model_total_gen  = (n.generators_t.p.sum().sum() +
                    n.storage_units_t.p.clip(lower=0).sum().sum()) / TWH

# VRE curtailment: available (p_max_pu * p_nom) minus actually dispatched
model_curtailment = 0.0
for gen_id, g in n.generators.iterrows():
    if g["carrier"] not in VRE_CARRIERS: continue
    if gen_id not in n.generators_t.p.columns: continue
    p_actual = n.generators_t.p[gen_id]
    if gen_id in n.generators_t.p_max_pu.columns:
        p_avail = n.generators_t.p_max_pu[gen_id] * g["p_nom"]
    else:
        p_avail = g.get("p_max_pu", 1.0) * g["p_nom"]
    model_curtailment += float((p_avail - p_actual).clip(lower=0).sum()) / TWH

# TYNDP values (from Yearly Outputs, our 52 buses)
tyndp_demand       = 3926.2
tyndp_phs_charge   = 111.2
tyndp_bat_charge   = 65.0
tyndp_electrolyser = 238.4
tyndp_curtailment  = 102.5
tyndp_total_gen    = 4470.4

rows = [
    ("Native Demand",          model_demand,        tyndp_demand),
    ("PHS pumping",            model_phs_charge,    tyndp_phs_charge),
    ("Battery charging",       model_bat_charge,    tyndp_bat_charge),
    ("Electrolyser (H2)",      0.0,                 tyndp_electrolyser),
    ("VRE curtailment",        model_curtailment,   tyndp_curtailment),
]

print("=" * 62)
print(f"  {'Sink':<28} {'Model TWh':>10} {'TYNDP TWh':>10}  {'Diff':>8}")
print("=" * 62)
for label, m, t in rows:
    print(f"  {label:<28} {m:10.1f} {t:10.1f}  {m-t:+8.1f}")
print("-" * 62)
print(f"  {'Total generation':<28} {model_total_gen:10.1f} {tyndp_total_gen:10.1f}  {model_total_gen-tyndp_total_gen:+8.1f}")
print("=" * 62)
print()
print("Note: Model curtailment = VRE available but not dispatched (never generated).")
print("      TYNDP dump energy = actually generated then discarded (p_min_pu constraints).")
print(f"      Electrolyser alone explains {tyndp_electrolyser:.0f} TWh of the "
      f"{model_total_gen - tyndp_total_gen:+.0f} TWh generation gap.")
# Out:
# ...
#   Sink                          Model TWh  TYNDP TWh      Diff
# ...
#   Native Demand                    3947.5     3926.2     +21.3
#   PHS pumping                       113.1      111.2      +1.9
#   Battery charging                   55.1       65.0      -9.9
#   Electrolyser (H2)                   0.0      238.4    -238.4
#   VRE curtailment                   157.2      102.5     +54.7
# --------------------------------------------------------------
#   Total generation                 4141.1     4470.4    -329.3
# ...
#
# Note: Model curtailment = VRE available but not dispatched (never generated).
#       TYNDP dump energy = actually generated then discarded (p_min_pu constraints).
#       Electrolyser alone explains 238 TWh of the -329 TWh generation gap.

# %% [markdown]
# ## Section 4 — Annual LMP — All Buses
#
# Scatter plot and ranked bar chart comparing annual average marginal prices across all buses.
# - **TYNDP:** `Yearly Outputs` row 218 — annual average excl. 3000 EUR/MWh price cap
# - **Model:** time-weighted mean of `buses_t.marginal_price`
#
# Note: TYNDP uses MILP (unit commitment) in Plexos; model uses LP (no commitment) → systematic downward bias expected.

# %%
# Section 4: Annual LMP — all buses — scatter + ranked bar chart

common_lmp_buses = sorted(set(tyndp_lmp.index) & set(model_lmp_annual.index))
t_lmp = np.array([tyndp_lmp[b] for b in common_lmp_buses])
m_lmp = np.array([float(model_lmp_annual.get(b, np.nan)) for b in common_lmp_buses])

valid = ~(np.isnan(t_lmp) | np.isnan(m_lmp))
t_v = t_lmp[valid]; m_v = m_lmp[valid]
buses_lmp = [b for b, ok in zip(common_lmp_buses, valid) if ok]
diff_lmp = m_v - t_v

rmse_lmp = np.sqrt(np.mean(diff_lmp ** 2))
mae_lmp  = np.mean(np.abs(diff_lmp))
bias_lmp = np.mean(diff_lmp)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(22, 7))

# Scatter
pad = 5
lims = [min(t_v.min(), m_v.min()) - pad, max(t_v.max(), m_v.max()) + pad]
ax1.plot(lims, lims, "k--", linewidth=0.8, alpha=0.5, label="1:1 line")
sc = ax1.scatter(t_v, m_v, c=diff_lmp, cmap="RdYlGn", vmin=-20, vmax=20, s=45, zorder=3)
plt.colorbar(sc, ax=ax1, label="Model − TYNDP [EUR/MWh]")
for i, bus in enumerate(buses_lmp):
    if abs(diff_lmp[i]) > 12:
        ax1.annotate(bus, (t_v[i], m_v[i]), fontsize=6, xytext=(3, 3), textcoords="offset points")
ax1.set_xlabel("TYNDP Annual Avg LMP [EUR/MWh]")
ax1.set_ylabel("Model Annual Avg LMP [EUR/MWh]")
ax1.set_title(f"Annual LMP — All Buses ({len(buses_lmp)} common)\n"
              f"RMSE={rmse_lmp:.1f}  MAE={mae_lmp:.1f}  Bias={bias_lmp:+.1f} EUR/MWh")
ax1.set_xlim(lims); ax1.set_ylim(lims)
ax1.legend(fontsize=9)
ax1.grid(alpha=0.3)

# Ranked bar: diff sorted
order = np.argsort(diff_lmp)
buses_s = [buses_lmp[i] for i in order]
diff_s = diff_lmp[order]
colors = ["#2196F3" if d >= 0 else "#F44336" for d in diff_s]
ax2.barh(range(len(buses_s)), diff_s, color=colors, edgecolor="white", linewidth=0.3)
ax2.axvline(0, color="black", linewidth=0.8)
ax2.axvline(bias_lmp, color="orange", linestyle="--", linewidth=1.5,
            label=f"Bias: {bias_lmp:+.1f} EUR/MWh")
ax2.set_yticks(range(len(buses_s)))
ax2.set_yticklabels(buses_s, fontsize=6)
ax2.set_xlabel("Model − TYNDP [EUR/MWh]")
ax2.set_title("LMP Diff by Bus (sorted)\nBlue = model higher | Red = model lower")
ax2.legend(fontsize=9)
ax2.grid(axis="x", alpha=0.3)

plt.tight_layout()
# Percentage diff bar chart
pct_diff = np.array([(m_v[i] - t_v[i]) / t_v[i] * 100 if t_v[i] != 0 else 0 for i in range(len(t_v))])
order_pct = np.argsort(pct_diff)
buses_pct = [buses_lmp[i] for i in order_pct]
pct_s = pct_diff[order_pct]
colors_pct = ["#2196F3" if d >= 0 else "#F44336" for d in pct_s]
ax3.barh(range(len(buses_pct)), pct_s, color=colors_pct, edgecolor="white", linewidth=0.3)
ax3.axvline(0, color="black", linewidth=0.8)
bias_pct = np.mean(pct_diff)
ax3.axvline(bias_pct, color="orange", linestyle="--", linewidth=1.5,
            label=f"Bias: {bias_pct:.1f}%")
ax3.set_yticks(range(len(buses_pct)))
ax3.set_yticklabels(buses_pct, fontsize=6)
ax3.set_xlabel("(Model − TYNDP) / TYNDP [%]")
ax3.set_title("LMP Diff by Bus [%] (sorted)\nBlue = model higher | Red = model lower")
ax3.legend(fontsize=9)
ax3.grid(axis="x", alpha=0.3)

plt.tight_layout()
plt.show()

# Print table
print(f"\n{'Bus':<6} {'TYNDP':>8} {'Model':>8} {'Diff':>8} {'Diff%':>8}")
print("-" * 34)
for bus in sorted(buses_lmp):
    i = buses_lmp.index(bus)
    t, m, d = t_v[i], m_v[i], diff_lmp[i]
    flag = "  !" if abs(d) > 15 else ""
    pct = d / t * 100 if t != 0 else 0
    print(f"{bus:<6} {t:8.2f} {m:8.2f} {d:+8.2f} {pct:+7.1f}%{flag}")
# Out:
# Bus       TYNDP    Model     Diff    Diff%
# ----------------------------------
# AL00      82.99    76.11    -6.88    -8.3%
# AT00      67.48    66.95    -0.54    -0.8%
# BA00      81.78    80.30    -1.48    -1.8%
# BE00      60.77    61.45    +0.67    +1.1%
# BG00      83.53    77.64    -5.90    -7.1%
# CH00      67.43    66.72    -0.71    -1.0%
# CY00      92.56    77.34   -15.22   -16.4%  !
# CZ00      79.71    76.62    -3.09    -3.9%
# DE00      61.42    61.74    +0.32    +0.5%
# DKE1      54.07    39.70   -14.37   -26.6%
# DKW1      56.21    53.56    -2.66    -4.7%
# EE00      52.41    48.25    -4.16    -7.9%
# ES00      41.85    18.84   -23.01   -55.0%  !
# FI00      41.19    32.40    -8.79   -21.3%
# FR00      59.62    54.52    -5.09    -8.5%
# FR15     174.25   247.59   +73.34   +42.1%  !
# GB00      42.90    36.70    -6.19   -14.4%
# GBNI      31.16    29.97    -1.19    -3.8%
# GR00      83.11    76.68    -6.42    -7.7%
# GR03      90.09    76.57   -13.51   -15.0%
# ...

# %%
# Annual LMP scatter (thesis) — Slovak labels, styled via plot_utils
_common = sorted(set(tyndp_lmp.index) & set(model_lmp_annual.index))
_t = np.array([tyndp_lmp[b] for b in _common])
_m = np.array([float(model_lmp_annual.get(b, np.nan)) for b in _common])
_ok = ~(np.isnan(_t) | np.isnan(_m))
_tv = _t[_ok]; _mv = _m[_ok]
_buses = [b for b, ok in zip(_common, _ok) if ok]
_diff = _mv - _tv

_keep = np.array([abs(d) < 50 and t < 150 and m < 150 for d, t, m in zip(_diff, _tv, _mv)])
_tv2 = _tv[_keep]; _mv2 = _mv[_keep]; _diff2 = _diff[_keep]
_buses2 = [b for b, k in zip(_buses, _keep) if k]
_removed = [b for b, k in zip(_buses, _keep) if not k]
_rmse2 = np.sqrt(np.mean(_diff2**2))
_mae2 = np.mean(np.abs(_diff2))
_bias2 = np.mean(_diff2)

fig, ax = thesis_subplots('single_tall')
pad = 5
lims = [min(_tv2.min(), _mv2.min()) - pad, max(_tv2.max(), _mv2.max()) + pad]
ax.plot(lims, lims, '--', color=REFLINE, linewidth=0.8, alpha=0.4, label='1:1')
sc = ax.scatter(_tv2, _mv2, c=_diff2, cmap='RdYlGn', vmin=-20, vmax=20,
                s=30, zorder=3, edgecolors='#333', linewidth=0.3)
cbar = plt.colorbar(sc, ax=ax)
cbar.set_label('Model \u2212 TYNDP [EUR/MWh]')

for i, bus in enumerate(_buses2):
    if abs(_diff2[i]) > 8 or bus in ['DE00', 'FR00']:
        ax.annotate(bus, (_tv2[i], _mv2[i]),
                    xytext=(4, 4), textcoords='offset points')

ax.set_xlabel('TYNDP \u2014 priemerná ročná LMP [EUR/MWh]')
ax.set_ylabel('Model \u2014 priemerná ročná LMP [EUR/MWh]')
ax.set_title(f'{len(_buses2)} zón    RMSE = {_rmse2:.1f}    MAE = {_mae2:.1f}    Bias = {_bias2:+.1f}')

ax.set_xlim(lims); ax.set_ylim(lims)
ax.legend(loc='upper left')

save_fig(fig, 'annual_lmp')
plt.show()
print(f'Removed: {_removed}')
# Out:
# Saved /Users/radovanhodor/Documents/TUKE/Final diplomova praca/tukedip_pdflatex_utf-8/figures/fig_annual_lmp.jpg
# Removed: ['FR15']

# %% [markdown]
# ## Section 8b — TYNDP Energy Not Served (Hourly Market Data)
#
# Detailed comparison of slack/unserved energy using hourly data from TYNDP "Hourly Market Data" sheet ("Energy Not Served [MW]" category). Compares monthly and per-bus breakdown between both models.

# %%
# Section 8b — TYNDP ENS from Hourly Market Data vs Model Slack

# ── Load TYNDP hourly "Energy Not Served" ─────────────────────────────────────
df_head = pd.read_excel(XLSX, sheet_name="Hourly Market Data", header=None,
                        nrows=13, engine="openpyxl")
cats = df_head.iloc[10, 2:]       # row 11 = category names
countries = df_head.iloc[11, 2:]   # row 12 = bus codes

ens_mask = cats == "Energy Not Served [MW]"
ens_cols_idx = cats[ens_mask].index.tolist()
ens_buses = countries[ens_mask].values

df_hourly = pd.read_excel(XLSX, sheet_name="Hourly Market Data", header=None,
                          skiprows=13, engine="openpyxl")
tyndp_ens = df_hourly[ens_cols_idx].copy()
tyndp_ens.columns = ens_buses

# ── Monthly breakdown ─────────────────────────────────────────────────────────
hours_per_month = [744, 672, 744, 720, 744, 720, 744, 744, 720, 744, 720, 744]
month_idx = np.repeat(np.arange(12), hours_per_month)[:len(tyndp_ens)]

tyndp_monthly = tyndp_ens.sum(axis=1).groupby(month_idx).sum() / GWH
tyndp_monthly.index = MONTH_NAMES

# ── Per-bus breakdown ─────────────────────────────────────────────────────────
tyndp_per_bus = (tyndp_ens.sum() / GWH).sort_values(ascending=False)
tyndp_per_bus = tyndp_per_bus[tyndp_per_bus > 0.001]

# ── Plot: side-by-side monthly comparison ─────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# Left: monthly comparison (Model vs TYNDP)
ax = axes[0]
x = np.arange(12)
w = 0.35
ax.bar(x - w/2, slack_monthly, w, label=f"Model ({slack_monthly.sum():.1f} GWh)", color="#c0392b", alpha=0.85)
ax.bar(x + w/2, tyndp_monthly.values, w, label=f"TYNDP ({tyndp_monthly.sum():.1f} GWh)", color="#1565C0", alpha=0.85)
ax.set_xticks(x)
ax.set_xticklabels(MONTH_NAMES)
ax.set_ylabel("Energy Not Served [GWh/month]")
ax.set_title("Monthly Slack/ENS — Model vs TYNDP", fontweight="bold")
ax.legend(fontsize=9)
ax.grid(axis="y", alpha=0.3)

# Right: per-bus comparison (top 10 from either model)
ax2 = axes[1]
all_buses = sorted(set(list(tyndp_per_bus.index) + list(slack_by_bus[slack_by_bus > 0.01].index)))
model_vals = [slack_by_bus.get(b, 0) for b in all_buses]
tyndp_vals = [tyndp_per_bus.get(b, 0) for b in all_buses]
# Sort by max of either
order = sorted(range(len(all_buses)), key=lambda i: max(model_vals[i], tyndp_vals[i]), reverse=True)
all_buses = [all_buses[i] for i in order][:10]
model_vals = [model_vals[i] for i in order][:10]
tyndp_vals = [tyndp_vals[i] for i in order][:10]
# 
y = np.arange(len(all_buses))
ax2.barh(y - 0.17, model_vals, 0.34, label="Model", color="#c0392b", alpha=0.85)
ax2.barh(y + 0.17, tyndp_vals, 0.34, label="TYNDP", color="#1565C0", alpha=0.85)
ax2.set_yticks(y)
ax2.set_yticklabels(all_buses)
ax2.set_xlabel("Annual ENS [GWh]")
ax2.set_title("Per-Bus Slack/ENS — Model vs TYNDP", fontweight="bold")
ax2.legend(fontsize=9)
ax2.grid(axis="x", alpha=0.3)
ax2.invert_yaxis()

plt.tight_layout()
plt.show()

# ── Summary table ─────────────────────────────────────────────────────────────
print(f"\n{'Month':<5} {'Model GWh':>12} {'TYNDP GWh':>12} {'Diff':>10}")
print("-" * 42)
for mo in range(12):
    m_val = slack_monthly[mo]
    t_val = tyndp_monthly.values[mo]
    print(f"{MONTH_NAMES[mo]:<5} {m_val:12.2f} {t_val:12.2f} {m_val - t_val:10.2f}")
print("-" * 42)
print(f"{'Total':<5} {slack_monthly.sum():12.2f} {tyndp_monthly.sum():12.2f} {slack_monthly.sum() - tyndp_monthly.sum():10.2f}")

print(f"\nTop buses with ENS:")
print(f"{'Bus':<8} {'Model GWh':>12} {'TYNDP GWh':>12}")
print("-" * 35)
for b in all_buses:
    m = slack_by_bus.get(b, 0)
    t = tyndp_per_bus.get(b, 0)
    print(f"{b:<8} {m:12.2f} {t:12.2f}")
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x1121fd550>>
# Traceback (most recent call last):
#   File "/Users/radovanhodor/Library/Python/3.12/lib/python/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
# Slack as percentage of total annual generation
model_gen_twh = 4141.0
tyndp_gen_twh = 4489.0
model_slack_gwh = slack_monthly.sum()
tyndp_slack_gwh = tyndp_monthly.sum()

print("=== Slack as % of total annual generation ===")
print(f"Model:  {model_slack_gwh:.1f} GWh / {model_gen_twh:.0f} TWh = {model_slack_gwh / (model_gen_twh * 1000) * 100:.4f}%")
print(f"TYNDP:  {tyndp_slack_gwh:.1f} GWh / {tyndp_gen_twh:.0f} TWh = {tyndp_slack_gwh / (tyndp_gen_twh * 1000) * 100:.4f}%")
# Out:
# === Slack as % of total annual generation ===
# Model:  96.0 GWh / 4141 TWh = 0.0023%
# TYNDP:  65.4 GWh / 4489 TWh = 0.0015%
